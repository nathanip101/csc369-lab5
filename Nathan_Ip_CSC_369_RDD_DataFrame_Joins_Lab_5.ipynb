# %% [markdown]
# # RDD / DataFrame Joins - Lab 5
#
# Reference/API Links
#
#
# *   [Apache Spark Quick Start](https://spark.apache.org/docs/3.3.0/quick-start.html)
# *   [PySpark v3.3.0 API](https://spark.apache.org/docs/3.3.0/api/python/reference/index.html)
# *    [RDD Programming Guide](https://spark.apache.org/docs/3.3.0/rdd-programming-guide.html)
# *    [Spark SQL Programming Guide](https://spark.apache.org/docs/3.3.0/sql-programming-guide.html)

# %%
# !pip install pyspark
# !pip install -U -q PyDrive
# !apt install openjdk-8-jdk-headless -qq
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# openjdk-8-jdk-headless is already the newest version (8u372-ga~us1-0ubuntu1~22.04).
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.

# %% [markdown]
# # Imports

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, SQLContext
from pyspark.sql import types as sparktypes
from pyspark.sql.functions import col

sc = SparkContext()
spark = SparkSession(sc)

# %%
# download sample access log / hostnames_country.csv for use in code below
# !rm -f apache.access.log
# !wget -q https://raw.githubusercontent.com/databricks/reference-apps/master/logs_analyzer/data/apache.access.log

# !rm -f hostname_country.csv
# !wget -q https://cpslo-my.sharepoint.com/:x:/g/personal/amigler_calpoly_edu/EcJv6-ZtZR5PpTEcKuDcYmsBq38YIwrNL6d6JtVztjrkhA?rtime=gKcu8Dc82kg\&download=1 -O hostname_country.csv

# %% [markdown]
# # Apache HTTP Log - Resilient Distributed Dataset (RDD)
#
# A SparkContext instance can be used to create RDDs from various data/files/resources (text files, CSV, Hadoop data files, etc.)

# %%
# find the top 10 clients, map/reduce style using RDD transformations
access_log_rdd = (sc.textFile("apache.access.log")
                  .map(lambda line: ( line.split(" ")[0], 1 ))  # field 0 = client address
                  .reduceByKey(lambda x, y: x + y)
                  .sortBy(lambda t: -t[1]))

print ("Total count of client hostnames:")
print(access_log_rdd.count())

print ("Top 10 client hostnames:")
print(access_log_rdd.take(10))
# Out:
# Total count of client hostnames:
# 169
# Top 10 client hostnames:
# [('64.242.88.10', 452), ('10.0.0.153', 188), ('cr020r01-3.sac.overture.com', 44), ('h24-71-236-129.ca.shawcable.net', 36), ('h24-70-69-74.ca.shawcable.net', 32), ('market-mail.panduit.com', 29), ('ts04-ip92.hevanet.com', 28), ('ip68-228-43-49.tc.ph.cox.net', 22), ('proxy0.haifa.ac.il', 19), ('207.195.59.160', 15)]

# %% [markdown]
# # Apache HTTP Log - DataFrame
#
# A DataFrame is equivalent to a relational table in Spark SQL, and can be created from on a variety of input formats (CSV, JSON, relational database, etc.) using the SparkSession.

# %%
access_log_df = spark.read.options(delimiter=" ").csv("apache.access.log")

named_df = access_log_df.select(col('_c0').alias('host'),
                                col('_c3').alias('timestamp'),
                                col('_c5').alias('path'),
                                col('_c6').cast('integer').alias('status'),
                                col('_c7').cast('integer').alias('content_size'))



named_df.show(truncate=False)
named_df.printSchema()
# Out:
# +------------+---------------------+-------------------------------------------------------------------------------------------------+------+------------+
# |host        |timestamp            |path                                                                                             |status|content_size|
# +------------+---------------------+-------------------------------------------------------------------------------------------------+------+------------+
# |64.242.88.10|[07/Mar/2004:16:05:49|GET /twiki/bin/edit/Main/Double_bounce_sender?topicparent=Main.ConfigurationVariables HTTP/1.1   |401   |12846       |
# |64.242.88.10|[07/Mar/2004:16:06:51|GET /twiki/bin/rdiff/TWiki/NewUserTemplate?rev1=1.3&rev2=1.2 HTTP/1.1                            |200   |4523        |
# |64.242.88.10|[07/Mar/2004:16:10:02|GET /mailman/listinfo/hsdivision HTTP/1.1                                                        |200   |6291        |
# |64.242.88.10|[07/Mar/2004:16:11:58|GET /twiki/bin/view/TWiki/WikiSyntax HTTP/1.1                                                    |200   |7352        |
# |64.242.88.10|[07/Mar/2004:16:20:55|GET /twiki/bin/view/Main/DCCAndPostFix HTTP/1.1                                                  |200   |5253        |
# |64.242.88.10|[07/Mar/2004:16:23:12|GET /twiki/bin/oops/TWiki/AppendixFileSystem?template=oopsmore&param1=1.12&param2=1.12 HTTP/1.1  |200   |11382       |
# |64.242.88.10|[07/Mar/2004:16:24:16|GET /twiki/bin/view/Main/PeterThoeny HTTP/1.1                                                    |200   |4924        |
# |64.242.88.10|[07/Mar/2004:16:29:16|GET /twiki/bin/edit/Main/Header_checks?topicparent=Main.ConfigurationVariables HTTP/1.1          |401   |12851       |
# |64.242.88.10|[07/Mar/2004:16:30:29|GET /twiki/bin/attach/Main/OfficeLocations HTTP/1.1                                              |401   |12851       |
# |64.242.88.10|[07/Mar/2004:16:31:48|GET /twiki/bin/view/TWiki/WebTopicEditTemplate HTTP/1.1                                          |200   |3732        |
# |64.242.88.10|[07/Mar/2004:16:32:50|GET /twiki/bin/view/Main/WebChanges HTTP/1.1                                                     |200   |40520       |
# |64.242.88.10|[07/Mar/2004:16:33:53|GET /twiki/bin/edit/Main/Smtpd_etrn_restrictions?topicparent=Main.ConfigurationVariables HTTP/1.1|401   |12851       |
# |64.242.88.10|[07/Mar/2004:16:35:19|GET /mailman/listinfo/business HTTP/1.1                                                          |200   |6379        |
# |64.242.88.10|[07/Mar/2004:16:36:22|GET /twiki/bin/rdiff/Main/WebIndex?rev1=1.2&rev2=1.1 HTTP/1.1                                    |200   |46373       |
# |64.242.88.10|[07/Mar/2004:16:37:27|GET /twiki/bin/view/TWiki/DontNotify HTTP/1.1                                                    |200   |4140        |
# |64.242.88.10|[07/Mar/2004:16:39:24|GET /twiki/bin/view/Main/TokyoOffice HTTP/1.1                                                    |200   |3853        |
# |64.242.88.10|[07/Mar/2004:16:43:54|GET /twiki/bin/view/Main/MikeMannix HTTP/1.1                                                     |200   |3686        |
# |64.242.88.10|[07/Mar/2004:16:45:56|GET /twiki/bin/attach/Main/PostfixCommands HTTP/1.1                                              |401   |12846       |
# |64.242.88.10|[07/Mar/2004:16:47:12|GET /robots.txt HTTP/1.1                                                                         |200   |68          |
# |64.242.88.10|[07/Mar/2004:16:47:46|GET /twiki/bin/rdiff/Know/ReadmeFirst?rev1=1.5&rev2=1.4 HTTP/1.1                                 |200   |5724        |
# +------------+---------------------+-------------------------------------------------------------------------------------------------+------+------------+
# only showing top 20 rows
#
# root
#  |-- host: string (nullable = true)
#  |-- timestamp: string (nullable = true)
#  |-- path: string (nullable = true)
#  |-- status: integer (nullable = true)
#  |-- content_size: integer (nullable = true)

# %% [markdown]
# # Part 1: Reporting Tasks from Prior Lab
#
# 1.   Given an Apache HTTP access log, along with a CSV file that includes country information for hostnames (sample file: [hostname_country.csv](https://cpslo-my.sharepoint.com/:x:/g/personal/amigler_calpoly_edu/EcJv6-ZtZR5PpTEcKuDcYmsBq38YIwrNL6d6JtVztjrkhA?e=xTmRdh)), produce a report that shows the total request count for each country, sorted by request count (highest to lowest)
# 2.   Using the same two input files (access.log and [hostname_country.csv](https://cpslo-my.sharepoint.com/:x:/g/personal/amigler_calpoly_edu/EcJv6-ZtZR5PpTEcKuDcYmsBq38YIwrNL6d6JtVztjrkhA?e=xTmRdh)), produce a report that lists, for each country, the count of each URL visited. Sort by country (alphabetically, A-Z) then count (from highest to lowest), For example:
#
# ```
#   Argentina  /home   115
#   Argentina /another/page.html  105
#   ...
#   United States  /robots.txt   185
#   United States /another/page.html  120
#   Uruguay  /home  310
#   Uruguay  /another/page.html  120
# ```

# %% [markdown]
# # (A) RDD Implementations
#
# Perform reporting tasks 1 and 2 using RDD transformations
#
# [RDD APIs PySpark v3.3.0](https://spark.apache.org/docs/3.3.0/api/python/reference/pyspark.html#rdd-apis)

# %%
# RDD implementation
# (1) Given an Apache HTTP access log, along with a CSV file that includes country information for
# hostnames (sample file: [hostname_country.csv](https://cpslo-my.sharepoint.com/:x:/g/personal/amigler_calpoly_edu/EcJv6-ZtZR5PpTEcKuDcYmsBq38YIwrNL6d6JtVztjrkhA?e=xTmRdh)),
# produce a report that shows the total request count for each country, sorted by request count (highest to lowest)

access_log_rdd = (sc.textFile("apache.access.log")
                  .map(lambda line: ( line.split(" ")[0], 1 ))
                  .reduceByKey(lambda x, y: x + y)
                  .sortBy(lambda t: -t[1])
                  )

hostnames_rdd = (sc.textFile("hostname_country.csv")
                  .map(lambda line: ( line.split(",")[0], line.split(",")[1] )))
joined_rdd = access_log_rdd.join(hostnames_rdd)
counts_rdd = (joined_rdd
                  .map(lambda x: ( x[1][1], x[1][0]))
                  .reduceByKey(lambda x, y: x + y)
                  .sortBy(lambda t: -t[1]))

for country, count in counts_rdd.collect():
  print(f"{country}\t{count}")
# Out:
# Unknown Location	812
# Intranet	198
# Canada	127
# United States	87
# Robot	80
# Israel	19
# Australia	17
# France	16
# Wherever You Want to Ship	13
# Germany	13
# United Kingdom	6
# Denmark	4
# Korea	4
# Spain	4
# Netherlands	2
# Finland	1
# Mexico	1
# Los Alamos	1
# Taiwan	1

# %%
# RDD implementation
# (2) Using the same two input files (access.log and hostname_country.csv), produce a report that lists,
# for each country, the count of each URL visited. Sort by country (alphabetically, A-Z) then count (from highest to lowest)
access_log_rdd = (sc.textFile("apache.access.log")
                  .map(lambda line: ( line.split(" ")[0], line.split(" ")[6] ))
                  .map(lambda x: ( (x[0], x[1]), 1 ))
                  .reduceByKey(lambda x, y: x + y)
                  .map(lambda x: ( x[0][0], (x[0][1], x[1])))
                  )
hostnames_rdd = (sc.textFile("hostname_country.csv")
                  .map(lambda line: ( line.split(",")[0], line.split(",")[1] )))
joined_rdd = access_log_rdd.join(hostnames_rdd)
counts_rdd = (joined_rdd
                  .map(lambda x: ( x[1][1], x[1][0]))
                  )
print(counts_rdd.collect())
sorted_counts_rdd = counts_rdd.sortBy(lambda x: (x[0], -x[1][1]))

for country, (url, count) in sorted_counts_rdd.collect():
  print(f"{country}\t{url}\t{count}")
# Out:
# [('Unknown Location', ('/robots.txt', 3)), ('Canada', ('/twiki/', 1)), ('Canada', ('/twiki/bin/view/Main/WebHome', 1)), ('Canada', ('/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif', 1)), ('Canada', ('/twiki/bin/view/Main/KevinWGagel', 1)), ('Canada', ('/twiki/view/Main/WebHome', 1)), ('Canada', ('/favicon.ico', 1)), ('Canada', ('/twiki/bin/view/Main/TWikiUsers', 1)), ('Robot', ('/twiki/bin/oops/TWiki/InterWikis', 1)), ('United States', ('/twiki/bin/view/Main/SpamAssassinAndPostFix', 1)), ('Germany', ('/SpamAssassin.html', 1)), ('Unknown Location', ('/twiki/bin/view/Main/WebHome', 1)), ('Unknown Location', ('/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif', 1)), ('Unknown Location', ('/', 1)), ('Unknown Location', ('/twiki/bin/view/Main/TWikiUsers', 1)), ('Unknown Location', ('/twiki/bin/view/Main/WebHome', 1)), ('Unknown Location', ('/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif', 1)), ('Unknown Location', ('/', 1)), ('Unknown Location', ('/favicon.ico', 2)), ('Unknown Location', ('/LateEmail.html', 1)), ('Unknown Location', ('/RBL.html', 1)), ('United States', ('/twiki/bin/view/Main/WebHome', 1)), ('United States', ('/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif', 1)), ('United States', ('/twiki/bin/view/Main/RelayGateway', 1)), ('United States', ('/twiki/bin/view/Main/Relay_Domains', 1)), ('United States', ('/twiki/bin/view/Main/VerifingGatway', 1)), ('Robot', ('/robots.txt', 1)), ('Unknown Location', ('/ie.htm', 1)), ('Unknown Location', ('/images/image005.jpg', 1)), ('Unknown Location', ('/images/msgops.JPG', 1)), ('Unknown Location', ('/', 1)), ('Unknown Location', ('/RBL.html', 1)), ('Unknown Location', ('/favicon.ico', 1)), ('Unknown Location', ('/images/image004.jpg', 1)), ('Unknown Location', ('/twiki/bin/view/Main/SpamAssassinTaggingOnly', 1)), ('Unknown Location', ('/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif', 1)), ('Canada', ('/mailman', 1)), ('Canada', ('/mailman/listinfo', 4)), ('Canada', ('/mailman/admin/ppwc', 9)), ('Canada', ('/icons/gnu-head-tiny.jpg', 1)), ('Canada', ('/mailman/admin/ppwc/members', 1)), ('Canada', ('/mailman/admin/ppwc/members?letter=n', 1)), ('Canada', ('/mailman/admin/ppwc/members?letter=p', 1)), ('Canada', ('/mailman/admin/ppwc/general', 1)), ('Canada', ('/mailman/admin/ppwc/?VARHELP=general/owner', 1)), ('Canada', ('/mailman/listinfo/ppwc', 7)), ('Canada', ('/mailman/admin/ppwc/logout', 1)), ('Canada', ('/icons/mailman.jpg', 1)), ('Canada', ('/icons/PythonPowered.png', 1)), ('Canada', ('/mailman/admin/ppwc/passwords', 1)), ('Canada', ('/mailman/admin/ppwc/gateway', 2)), ('Canada', ('/mailman/admindb/ppwc', 3)), ('Unknown Location', ('/twiki/bin/view/Main/WebHome', 1)), ('Unknown Location', ('/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif', 1)), ('Unknown Location', ('/twiki/bin/view/Sandbox/WebHome', 1)), ('Unknown Location', ('/favicon.ico', 1)), ('Unknown Location', ('/twiki/bin/view/Main/RBLsHowTo', 1)), ('United States', ('/razor.html', 1)), ('Netherlands', ('/SpamAssassin.html', 1)), ('Unknown Location', ('/razor.html', 1)), ('Spain', ('/twiki/bin/view/Main/WebHome', 1)), ('Spain', ('/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif', 1)), ('Spain', ('/twiki/bin/view/Main/PostfixCommands', 1)), ('Spain', ('/twiki/bin/view/Main/PostSuper', 1)), ('Robot', ('/robots.txt', 8)), ('Canada', ('/cgi-bin/mailgraph2.cgi', 2)), ('Canada', ('/cgi-bin/mailgraph.cgi/mailgraph_0.png', 2)), ('Canada', ('/cgi-bin/mailgraph.cgi/mailgraph_1.png', 2)), ('Canada', ('/cgi-bin/mailgraph.cgi/mailgraph_1_err.png', 2)), ('Canada', ('/dccstats/index.html', 1)), ('Canada', ('/dccstats/stats-spam.1day.png', 1)), ('Canada', ('/dccstats/stats-spam.1week.png', 1)), ('Canada', ('/dccstats/stats-spam-ratio.1week.png', 1)), ('Canada', ('/dccstats/stats-spam-ratio.1month.png', 1)), ('Canada', ('/', 1)), ('Canada', ('/favicon.ico', 1)), ('Canada', ('/cgi-bin/mailgraph.cgi/mailgraph_0_err.png', 2)), ('Canada', ('/cgi-bin/mailgraph.cgi/mailgraph_2.png', 2)), ('Canada', ('/cgi-bin/mailgraph.cgi/mailgraph_2_err.pn ...
# Australia	/mailman/listinfo	2
# Australia	/twiki/bin/view/Main/SpamAssassinAndPostFix	2
# Australia	/twiki/bin/view/Main/SpamAssassinDeleting	2
# Australia	/mailman/admin	1
# Australia	/icons/gnu-head-tiny.jpg	1
# Australia	/mailman	1
# Australia	/icons/mailman.jpg	1
# Australia	/icons/PythonPowered.png	1
# Australia	/mailman/admin/webct	1
# Australia	/mailman/listinfo/administration	1
# Australia	/mailman/listinfo/cnc_notice	1
# Australia	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Australia	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Australia	/twiki/bin/view/Main/WebHome	1
# Canada	/mailman/admin/ppwc	9
# Canada	/mailman/listinfo/ppwc	7
# Canada	/mailman/listinfo	4
# Canada	/mailman/admindb/ppwc	3
# Canada	/mailman/admin/ppwc/gateway	2
# Canada	/cgi-bin/mailgraph2.cgi	2
# Canada	/cgi-bin/mailgraph.cgi/mailgraph_0.png	2
# Canada	/cgi-bin/mailgraph.cgi/mailgraph_1.png	2
# Canada	/cgi-bin/mailgraph.cgi/mailgraph_1_err.png	2
# Canada	/cgi-bin/mailgraph.cgi/mailgraph_0_err.png	2
# Canada	/cgi-bin/mailgraph.cgi/mailgraph_2.png	2
# Canada	/cgi-bin/mailgraph.cgi/mailgraph_2_err.png	2
# Canada	/cgi-bin/mailgraph.cgi/mailgraph_3.png	2
# Canada	/cgi-bin/mailgraph.cgi/mailgraph_3_err.png	2
# Canada	/mailman/options/cnc_notice	2
# Canada	/images/image004.jpg	2
# Canada	/ie.htm	2
# Canada	/images/image005.jpg	2
# Canada	/images/msgops.JPG	2
# Canada	/twiki/	1
# Canada	/twiki/bin/view/Main/WebHome	1
# Canada	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Canada	/twiki/bin/view/Main/KevinWGagel	1
# Canada	/twiki/view/Main/WebHome	1
# Canada	/favicon.ico	1
# Canada	/twiki/bin/view/Main/TWikiUsers	1
# Canada	/mailman	1
# Canada	/icons/gnu-head-tiny.jpg	1
# Canada	/mailman/admin/ppwc/members	1
# Canada	/mailman/admin/ppwc/members?letter=n	1
# Canada	/mailman/admin/ppwc/members?letter=p	1
# Canada	/mailman/admin/ppwc/general	1
# Canada	/mailman/admin/ppwc/?VARHELP=general/owner	1
# Canada	/mailman/admin/ppwc/logout	1
# Canada	/icons/mailman.jpg	1
# Canada	/icons/PythonPowered.png	1
# Canada	/mailman/admin/ppwc/passwords	1
# Canada	/dccstats/index.html	1
# Canada	/dccstats/stats-spam.1day.png	1
# Canada	/dccstats/stats-spam.1week.png	1
# Canada	/dccstats/stats-spam-ratio.1week.png	1
# Canada	/dccstats/stats-spam-ratio.1month.png	1
# Canada	/	1
# Canada	/favicon.ico	1
# Canada	/dccstats/stats-spam-ratio.1day.png	1
# Canada	/dccstats/stats-hashes.1week.png	1
# Canada	/dccstats/stats-spam.1month.png	1
# Canada	/dccstats/stats-hashes.1month.png	1
# Canada	/dccstats/stats-spam.1year.png	1
# Canada	/dccstats/stats-spam-ratio.1year.png	1
# Canada	/dccstats/stats-hashes.1year.png	1
# Canada	/ie.htm	1
# Canada	/images/image005.jpg	1
# Canada	/images/msgops.JPG	1
# Canada	/mailman/options/cnc_notice/arobin%40shaw.c	1
# Canada	/icons/mailman.jpg	1
# Canada	/icons/PythonPowered.png	1
# Canada	/icons/gnu-head-tiny.jpg	1
# Canada	/pipermail/cncce/2004-January/000001.html	1
# Canada	/ie.htm	1
# Canada	/images/image005.jpg	1
# Canada	/images/msgops.JPG	1
# Canada	/images/image004.jpg	1
# Canada	/ie.htm	1
# Canada	/images/image005.jpg	1
# Canada	/images/msgops.JPG	1
# Canada	/images/image004.jpg	1
# Canada	/mailman	1
# Canada	/mailman/listinfo	1
# Canada	/icons/gnu-head-tiny.jpg	1
# Canada	/	1
# Canada	/icons/mailman.jpg	1
# Canada	/icons/PythonPowered.png	1
# Canada	/mailman/listinfo/ppwc	1
# Canada	/pipermail/cnc_notice/2003-December.txt	1
# Canada	/pipermail/cnc_notice/2003-December/000002.html	1
# Canada	/pipermail/cnc_notice/2004-February.txt	1
# Canada	/images/image004.jpg	1
# Canada	/mailman/listinfo/ppwc	1
# Canada	/icons/mailman.jpg	1
# Canada	/icons/PythonPowered.png	1
# Canada	/icons/gnu-head-tiny.jpg	1
# Canada	/	1
# Canada	/RBL.html	1
# Canada	/SpamAssassin.html	1
# Canada	/	1
# Canada	/icons/mailman.jpg	1
# Canada	/icons/PythonPowered.png	1
# Canada	/mailman/listinfo/administration	1
# Canada	/mailman	1
# Canada	/mailman/listinfo	1
# Canada	/icons/gnu-head-tiny.jpg	1
# Canada	/LateEmail.html	1
# Denmark	/favicon.ico	1
# Denmark	/razor.html	1
# Denmark	/twiki/bin/view/Main/WebHome	1
# Denmark	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Finland	/razor.html	1
# France	/twiki/bin/view/Main/WebHome	1
# France	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# France	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# France	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# France	/twiki/bin/view/Main/SpamAssassinDeleting	1
# France	/twiki/bin/view/Main/ConfigurationVariables	1
# France	/twiki/pub/TWiki/TWikiLogos/twikiRobot131x64.gif	1
# France	/twiki/bin/view/Sandbox/WebHome	1
# France	/twiki/bin/view/Main/SpamAssassin	1
# France	/twiki/bin/view/Main/DCCAndPostFix	1
# France	/twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC	1
# France	/twiki/bin/view/TWiki/WebHome	1
# France	/twiki/pub/TWiki/TWikiDocGraphics/tip.gif	1
# France	/twiki/pub/TWiki/TWikiLogos/twikiRobot88x31.gif	1
# France	/	1
# France	/razor.html	1
# Germany	/twiki/bin/view/Main/WebHome	2
# Germany	/SpamAssassin.html	1
# Germany	/favicon.ico	1
# Germany	/twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC	1
# Germany	/twiki/bin/edit/Main/UvscanAndPostFix?topicparent=Main.WebHome	1
# Germany	/twiki/pub/TWiki/TWikiDocGraphics/help.gif	1
# Germany	/twiki/bin/view/Main/DCCAndPostFix	1
# Germany	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Germany	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# Germany	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Germany	/twiki/bin/view/Main/SpamAssassinDeleting	1
# Germany	/twiki/bin/view/Main/Postfix	1
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_0_err.png	12
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_2.png	12
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_2_err.png	12
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_3.png	12
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_3_err.png	12
# Intranet	/cgi-bin/mailgraph2.cgi	12
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_0.png	12
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_1_err.png	12
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_1.png	12
# Intranet	/dccstats/stats-spam-ratio.1day.png	5
# Intranet	/dccstats/stats-hashes.1month.png	5
# Intranet	/dccstats/stats-hashes.1week.png	5
# Intranet	/dccstats/stats-spam.1year.png	5
# Intranet	/dccstats/stats-spam.1month.png	5
# Intranet	/dccstats/stats-spam-ratio.1year.png	5
# Intranet	/dccstats/stats-hashes.1year.png	5
# Intranet	/dccstats/stats-spam.1day.png	5
# Intranet	/dccstats/stats-spam-ratio.1week.png	5
# Intranet	/dccstats/stats-spam.1week.png	5
# Intranet	/dccstats/stats-spam-ratio.1month.png	5
# Intranet	/mailman/admin/ppwc/members?letter=p	5
# Intranet	/twiki/bin/view/Main/WebHome	4
# Intranet	/mailman/admin/ppwc	3
# Intranet	/mailman/admin/ppwc/members	3
# Intranet	/mailman/admin/ppwc/members/add	2
# Intranet	/mailman/listinfo/ppwc	1
# Intranet	/mailman/options/ppwc/ppwctwentynine--at--shaw.com	1
# Intranet	/mailman/options/ppwc/ppwctwentynine@shaw.com	1
# Intranet	/mailman/admin/ppwc/logout	1
# Intranet	/mailman	1
# Intranet	/mailman/listinfo	1
# Intranet	/mailman/admin/ppwc/general	1
# Intranet	/mailman/admin/ppwc/members/list	1
# Intranet	/	1
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_0_err.png	1
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_2_err.png	1
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_2.png	1
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_3.png	1
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_3_err.png	1
# Intranet	/cgi-bin/mailgraph2.cgi	1
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_1_err.png	1
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_0.png	1
# Intranet	/cgi-bin/mailgraph.cgi/mailgraph_1.png	1
# Israel	/dccstats/index.html	1
# Israel	/dccstats/stats-spam.1week.png	1
# Israel	/dccstats/stats-spam.1day.png	1
# Israel	/dccstats/stats-spam-ratio.1week.png	1
# Israel	/dccstats/stats-spam-ratio.1month.png	1
# Israel	/SpamAssassin.html	1
# Israel	/razor.html	1
# Israel	/twiki/bin/view/Main/WebHome	1
# Israel	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Israel	/twiki/bin/view/Main/LinksOfUse	1
# Israel	/twiki/bin/view/Main/PostfixCommands	1
# Israel	/	1
# Israel	/dccstats/stats-spam-ratio.1day.png	1
# Israel	/dccstats/stats-hashes.1week.png	1
# Israel	/dccstats/stats-spam.1month.png	1
# Israel	/dccstats/stats-hashes.1month.png	1
# Israel	/dccstats/stats-spam.1year.png	1
# Israel	/dccstats/stats-spam-ratio.1year.png	1
# Israel	/dccstats/stats-hashes.1year.png	1
# Korea	/mailman/listinfo/cncce	1
# Korea	/icons/gnu-head-tiny.jpg	1
# Korea	/icons/mailman.jpg	1
# Korea	/icons/PythonPowered.png	1
# Los Alamos	/razor.html	1
# Mexico	/razor.html	1
# Netherlands	/SpamAssassin.html	1
# Netherlands	/	1
# Robot	/robots.txt	8
# Robot	/robots.txt	5
# Robot	/robots.txt	5
# Robot	/twiki/bin/view/Main/SanJoseOffice	2
# Robot	/twiki/bin/oops/TWiki/InterWikis	1
# Robot	/robots.txt	1
# Robot	/twiki/bin/oops/Sandbox/WebStatistics	1
# Robot	/twiki/bin/oops/Main/ThanadonSomdee	1
# Robot	/twiki/bin/oops/TWiki/WikiWikiClones	1
# Robot	/twiki/bin/oops/Main/Smtpd_recipient_limit	1
# Robot	/twiki/bin/oops/TWiki/Mana	1
# Robot	/twiki/bin/view/TWiki/2fa	1
# Robot	/twiki/bin/oops/Know/WinDoze95Crash	1
# Robot	/twiki/bin/oops/TWiki/RegularExp	1
# Robot	/twiki/bin/view/Sandbox/WebIndex	1
# Robot	/twiki/bin/oops/TWiki/WikiTopic	1
# Robot	/twiki/bin/oops/Main/KevinWGage	1
# Robot	/twiki/bin/view/Main/DCCGraphs	1
# Robot	/twiki/bin/oops/TWiki/TextFormattingRules	1
# Robot	/twiki/bin/oops/TWiki/TWikiVariables	1
# Robot	/twiki/bin/oops/TWiki/TWikiPlannedFeatures	1
# Robot	/twiki/bin/oops/TWiki/Wik	1
# Robot	/twiki/bin/view/TWiki/d43	1
# Robot	/twiki/bin/oops/TWiki/TWikiAccessControl	1
# Robot	/twiki/bin/oops/Main/SpamAssassinTaggingOnly	1
# Robot	/twiki/bin/oops/Main/TWikiUsers	1
# Robot	/twiki/bin/view/Main/VishaalGolam	1
# Robot	/twiki/bin/oops/Know/WebStatistics	1
# Robot	/twiki/bin/view/Know/WebStatistics	1
# Robot	/robots.txt	1
# Robot	/twiki/bin/view/Sandbox/WebHome	1
# Robot	/twiki/bin/view/Sandbox/WebChanges	1
# Robot	/twiki/bin/view/Sandbox/WebPreferences	1
# Robot	/twiki/bin/view/Main/WebStatistics	1
# Robot	/twiki/bin/view/Main/WebPreferences	1
# Robot	/twiki/bin/view/Main/WebSearch	1
# Robot	/twiki/bin/view/Main/WebTopicList	1
# Robot	/twiki/bin/view/Main/WebNotify	1
# Robot	/twiki/bin/oops/TWiki/1000	1
# Robot	/twiki/bin/view/Main/MikeMannix	1
# Robot	/twiki/bin/oops/Main/Mi	1
# Robot	/twiki/bin/view/Main/TWikiAdminGroup	1
# Robot	/twiki/bin/view/Main/LondonOffice	1
# Robot	/twiki/bin/oops/Know/PublicSupported	1
# Robot	/	1
# Robot	/twiki/bin/oops/Sandbox/WebChanges	1
# Robot	/twiki/bin/oops/Main/TWiki	1
# Robot	/twiki/bin/oops/TWiki/WebChangesAlert	1
# Robot	/twiki/bin/oops/TWiki/FileAttachment	1
# Robot	/twiki/bin/view/Main/TWi	1
# Robot	/twiki/bin/oops/Know/TopicClassification	1
# Robot	/twiki/bin/oops/Main/T	1
# Robot	/twiki/bin/view/Know/WebHome	1
# Robot	/twiki/bin/view/Main/DCCAndPostFix	1
# Robot	/twiki/bin/view/Main/SimonMudd	1
# Robot	/twiki/bin/oops/TWiki/MoveTopic	1
# Robot	/twiki/bin/oops/TWiki/NicholasLee	1
# Robot	/twiki/bin/oops/Main/WebStatistics	1
# Robot	/twiki/bin/oops/TWiki/JohnAltstadt	1
# Robot	/twiki/bin/oops/Main/TWi	1
# Robot	/robots.txt	1
# Robot	/twiki/bin/oops/TWiki/InterwikiPlugin	1
# Robot	/twiki/bin/oops/TWiki/TablePlugin	1
# Robot	/twiki/bin/oops/TWiki/SvenDowideit	1
# Spain	/twiki/bin/view/Main/WebHome	1
# Spain	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Spain	/twiki/bin/view/Main/PostfixCommands	1
# Spain	/twiki/bin/view/Main/PostSuper	1
# Taiwan	/M83A	1
# United Kingdom	/	1
# United Kingdom	/favicon.ico	1
# United Kingdom	/DCC.html	1
# United Kingdom	/razor.html	1
# United Kingdom	/favicon.ico	1
# United Kingdom	/razor.html	1
# United States	/twiki/bin/view/Main/WebHome	5
# United States	/favicon.ico	3
# United States	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	2
# United States	/twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC	2
# United States	/twiki/bin/view/Main/WebHome	2
# United States	/	2
# United States	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# United States	/twiki/bin/view/Main/WebHome	1
# United States	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# United States	/twiki/bin/view/Main/RelayGateway	1
# United States	/twiki/bin/view/Main/Relay_Domains	1
# United States	/twiki/bin/view/Main/VerifingGatway	1
# United States	/razor.html	1
# United States	/twiki/bin/view/Main/WebHome	1
# United States	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# United States	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# United States	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# United States	/favicon.ico	1
# United States	/twiki/bin/view/Main/DCC	1
# United States	/favicon.ico	1
# United States	/AmavisNew.html	1
# United States	/favicon.ico	1
# United States	/twiki/bin/view/Main/SideBar	1
# United States	/twiki/bin/view/Main/PostfixCmd	1
# United States	/twiki/bin/view/Main/PostSuper	1
# United States	/twiki/bin/view/Main/RBLsHowTo	1
# United States	/twiki/bin/edit/Main/Propagate_unmatched_extensions?topicparent=Main.ConfigurationVariables	1
# United States	/twiki/pub/TWiki/TWikiDocGraphics/help.gif	1
# United States	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# United States	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# United States	/twiki/bin/view/Main/LinksOfUse	1
# United States	/twiki/bin/view/Main/RelayGateway	1
# United States	/twiki/bin/view/Main/PostfixCommands	1
# United States	/twiki/bin/view/Main/ConfigurationVariables	1
# United States	/twiki/bin/view/Main/SpamAssassin	1
# United States	/twiki/bin/view/Main/TWikiGroups	1
# United States	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# United States	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# United States	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# United States	/twiki/bin/view/Main/PostfixCommands	1
# United States	/twiki/bin/view/Main/TWikiAdminGroup	1
# United States	/twiki/bin/view/Main/WebHome	1
# United States	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# United States	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# United States	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# United States	/twiki/bin/view/Main/SpamAssassinDeleting	1
# United States	/rejected.html	1
# United States	/mailman/listinfo/ppwc	1
# United States	/icons/mailman.jpg	1
# United States	/icons/PythonPowered.png	1
# United States	/icons/gnu-head-tiny.jpg	1
# United States	/twiki/bin/view/Main/SpamAssassinDeleting	1
# United States	/LateEmail.html	1
# United States	/twiki/bin/view/Main/SpamAssassinDeleting	1
# United States	/twiki/bin/view/Main/SpamAssassinDeleting	1
# United States	/mailman/listinfo/webber	1
# United States	/	1
# United States	/AmavisNew.html	1
# United States	/favicon.ico	1
# United States	/dccstats/stats-hashes.1week.png	1
# United States	/dccstats/stats-spam.1month.png	1
# United States	/dccstats/stats-spam-ratio.1day.png	1
# United States	/dccstats/stats-hashes.1month.png	1
# United States	/dccstats/stats-spam-ratio.1year.png	1
# United States	/dccstats/stats-spam.1year.png	1
# United States	/dccstats/stats-hashes.1year.png	1
# United States	/dccstats/index.html	1
# United States	/dccstats/stats-spam.1day.png	1
# United States	/dccstats/stats-spam.1week.png	1
# United States	/dccstats/stats-spam-ratio.1month.png	1
# United States	/dccstats/stats-spam-ratio.1week.png	1
# United States	/mailman/listinfo/ppwc	1
# United States	/mailman	1
# United States	/mailman/listinfo	1
# United States	/favicon.ico	1
# United States	/razor.html	1
# United States	/SpamAssassin.html	1
# Unknown Location	/clients.html	4
# Unknown Location	/robots.txt	3
# Unknown Location	/	3
# Unknown Location	/favicon.ico	2
# Unknown Location	/favicon.ico	2
# Unknown Location	/twiki/bin/view/Main/SpamAssassin	2
# Unknown Location	/	2
# Unknown Location	/robots.txt	2
# Unknown Location	/favicon.ico	2
# Unknown Location	/twiki/bin/view/Main/WebHome	2
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/	1
# Unknown Location	/twiki/bin/view/Main/TWikiUsers	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/	1
# Unknown Location	/LateEmail.html	1
# Unknown Location	/RBL.html	1
# Unknown Location	/ie.htm	1
# Unknown Location	/images/image005.jpg	1
# Unknown Location	/images/msgops.JPG	1
# Unknown Location	/	1
# Unknown Location	/RBL.html	1
# Unknown Location	/favicon.ico	1
# Unknown Location	/images/image004.jpg	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Sandbox/WebHome	1
# Unknown Location	/favicon.ico	1
# Unknown Location	/twiki/bin/view/Main/RBLsHowTo	1
# Unknown Location	/razor.html	1
# Unknown Location	/pipermail/cncce/2004-January/000001.html	1
# Unknown Location	/robots.txt	1
# Unknown Location	/twiki/bin/view/Main/WebHome?rev=1.25	1
# Unknown Location	/twiki/bin/view/Main/WebNotify?rev=r1.6	1
# Unknown Location	/twiki/bin/rdiff/TWiki/ManagingTopics?rev1=1.16&rev2=1.15	1
# Unknown Location	/twiki/bin/view/Main/WebHome?rev=r1.8	1
# Unknown Location	/twiki/bin/edit/Main/Max_idle?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Appendix%20*File%20*System%5B%5EA-Za-z%5D	1
# Unknown Location	/twiki/bin/view/TWiki/WebTopicViewTemplate	1
# Unknown Location	/twiki/bin/rdiff/Main/WebHome	1
# Unknown Location	/twiki/bin/view/TWiki/WebPreferences?rev=r1.9	1
# Unknown Location	/twiki/bin/rdiff/Main/ConfigurationVariables?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/view/Main/AndreaSterbini	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WebNotify	1
# Unknown Location	/twiki/bin/rdiff/Main/WebHome?rev1=1.28&rev2=1.27	1
# Unknown Location	/twiki/bin/view/Main/WebHome?skin=print	1
# Unknown Location	/twiki/bin/search/Main/SearchResult?search=%5C.*&scope=topic&order=modified&reverse=on&regex=on&nosearch=on	1
# Unknown Location	/twiki/bin/view/TWiki/AppendixFileSystem?rev=1.10	1
# Unknown Location	/twiki/bin/view/Know/WebNotify	1
# Unknown Location	/twiki/bin/view/Main/WebHome?skin=print&rev=1.25	1
# Unknown Location	/twiki/bin/edit/Main/Relayhost?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/edit/Main/Unknown_virtual_mailbox_reject_code?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/TWiki/WebPreferences	1
# Unknown Location	/twiki/bin/oops/Main/WebHome?template=oopsmore&param1=1.28&param2=1.28	1
# Unknown Location	/twiki/bin/view/Main/PostfixCommands	1
# Unknown Location	/twiki/bin/view/Main/WebHome?rev=1.27	1
# Unknown Location	/twiki/bin/view/Main/ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/TWiki/WebStatistics	1
# Unknown Location	/twiki/bin/view/Main/TWikiGuest	1
# Unknown Location	/twiki/bin/view/Main/WebChanges	1
# Unknown Location	/twiki/bin/oops/TWiki/AppendixFileSystem?template=oopsmore&param1=1.12&param2=1.12	1
# Unknown Location	/twiki/bin/rdiff/Main/AndreaSterbini	1
# Unknown Location	/twiki/bin/view/TWiki/FormattedSearch	1
# Unknown Location	/twiki/bin/oops/Main/WebHome?template=oopsmore&param1=1.28&param2=1.8	1
# Unknown Location	/twiki/bin/edit/TWiki/TextFormattingFAQ?t=1075982736	1
# Unknown Location	/twiki/bin/edit/Main/Allow_untrusted_routing?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/edit/Main/Smtp_data_init_timeout?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/Main/AndreaSterbini?rev=r1.1	1
# Unknown Location	/twiki/bin/rdiff/Main/PeterThoeny	1
# Unknown Location	/twiki/bin/view/Main/DCC	1
# Unknown Location	/twiki/bin/view/Know/WebHome	1
# Unknown Location	/twiki/bin/view/Main/WebNotify	1
# Unknown Location	/twiki/bin/view/TWiki/WebHome	1
# Unknown Location	/twiki/bin/view/Main/RBLsHowTo	1
# Unknown Location	/twiki/bin/view/Main/WebTopicList	1
# Unknown Location	/SpamAssassin.html	1
# Unknown Location	/dccstats/stats-spam.1day.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1week.png	1
# Unknown Location	/dccstats/stats-spam.1week.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1month.png	1
# Unknown Location	/dccstats/	1
# Unknown Location	/dccstats/stats-spam-ratio.1day.png	1
# Unknown Location	/dccstats/stats-hashes.1week.png	1
# Unknown Location	/dccstats/stats-spam.1month.png	1
# Unknown Location	/dccstats/stats-hashes.1month.png	1
# Unknown Location	/dccstats/stats-spam.1year.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1year.png	1
# Unknown Location	/dccstats/stats-hashes.1year.png	1
# Unknown Location	/dccstats/stats-spam.1day.png	1
# Unknown Location	/dccstats/stats-spam.1week.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1week.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1month.png	1
# Unknown Location	/dccstats/	1
# Unknown Location	/dccstats/stats-spam-ratio.1day.png	1
# Unknown Location	/dccstats/stats-hashes.1week.png	1
# Unknown Location	/dccstats/stats-spam.1month.png	1
# Unknown Location	/dccstats/stats-hashes.1month.png	1
# Unknown Location	/dccstats/stats-spam.1year.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1year.png	1
# Unknown Location	/dccstats/stats-hashes.1year.png	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/	1
# Unknown Location	/SpamAssassin.html	1
# Unknown Location	/RBL.html	1
# Unknown Location	/AmavisNew.html	1
# Unknown Location	/favicon.ico	1
# Unknown Location	/razor.html	1
# Unknown Location	/icons/mailman.jpg	1
# Unknown Location	/icons/PythonPowered.png	1
# Unknown Location	/mailman/listinfo/webber	1
# Unknown Location	/icons/gnu-head-tiny.jpg	1
# Unknown Location	/mailman/listinfo/fnac	1
# Unknown Location	/icons/PythonPowered.png	1
# Unknown Location	/icons/mailman.jpg	1
# Unknown Location	/icons/gnu-head-tiny.jpg	1
# Unknown Location	/twiki/bin/view/Main/DCCAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC	1
# Unknown Location	/twiki/bin/view/Main/PostfixCmd	1
# Unknown Location	/twiki/bin/view/Main/PostSuper	1
# Unknown Location	/twiki/bin/view/Main/RBLsHowTo	1
# Unknown Location	/twiki/bin/view/Main/VerifingGatway	1
# Unknown Location	/twiki/bin/view/Main/SideBar	1
# Unknown Location	/twiki/bin/view/Main/DCCGraphs	1
# Unknown Location	/twiki/bin/view/Main/PostfixCommands	1
# Unknown Location	/twiki/bin/view/Main/ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/Main/RelayGateway	1
# Unknown Location	/twiki/bin/view/Main/KevinWGagel	1
# Unknown Location	/twiki/bin/view/Main/LinksOfUse	1
# Unknown Location	/AmavisNew.html	1
# Unknown Location	/favicon.ico	1
# Unknown Location	/AmavisNew.html	1
# Unknown Location	/SpamAssassin.html	1
# Unknown Location	/AmavisNew.html	1
# Unknown Location	/	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/razor.html	1
# Unknown Location	/razor.html	1
# Unknown Location	/mailman/listinfo/webber	1
# Unknown Location	/razor.html	1
# Unknown Location	/pipermail/cncce/2004-January/000001.html	1
# Unknown Location	/pipermail/cncce/2004-January/000002.html	1
# Unknown Location	/pipermail/cncce/2004-January.txt	1
# Unknown Location	/_vti_bin/owssvr.dll?UL=1&ACT=4&BUILD=2614&STRMVER=4&CAPREQ=0	1
# Unknown Location	/SpamAssassin.html	1
# Unknown Location	/MSOffice/cltreq.asp?UL=1&ACT=4&BUILD=2614&STRMVER=4&CAPREQ=0	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinDeleting	1
# Unknown Location	/dccstats/index.html	1
# Unknown Location	/dccstats/stats-spam.1day.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1week.png	1
# Unknown Location	/dccstats/stats-spam.1week.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1month.png	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/	1
# Unknown Location	/dccstats/stats-spam-ratio.1day.png	1
# Unknown Location	/dccstats/stats-hashes.1week.png	1
# Unknown Location	/dccstats/stats-spam.1month.png	1
# Unknown Location	/dccstats/stats-hashes.1month.png	1
# Unknown Location	/dccstats/stats-spam.1year.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1year.png	1
# Unknown Location	/dccstats/stats-hashes.1year.png	1
# Unknown Location	/twiki/bin/view/Main/DCCAndPostFix	1
# Unknown Location	/dccstats/index.html	1
# Unknown Location	/dccstats/stats-spam.1day.png	1
# Unknown Location	/dccstats/stats-spam.1week.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1week.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1month.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1day.png	1
# Unknown Location	/dccstats/stats-hashes.1week.png	1
# Unknown Location	/dccstats/stats-spam.1month.png	1
# Unknown Location	/dccstats/stats-hashes.1month.png	1
# Unknown Location	/dccstats/stats-spam.1year.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1year.png	1
# Unknown Location	/dccstats/stats-hashes.1year.png	1
# Unknown Location	/favicon.ico	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassin	1
# Unknown Location	/twiki/bin/view/Main/DCCAndPostFix	1
# Unknown Location	/razor.html	1
# Unknown Location	/favicon.ico	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinDeleting	1
# Unknown Location	/twiki/bin/view/Main/ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/Main/PostfixCommands	1
# Unknown Location	/twiki/bin/view/Main/LinksOfUse	1
# Unknown Location	/twiki/bin/view/Main/RBLsHowTo	1
# Unknown Location	/twiki/bin/view/Main/PostSuper	1
# Unknown Location	/twiki/bin/view/Main/DCCAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC	1
# Unknown Location	/twiki/bin/view/Main/SideBar	1
# Unknown Location	/twiki/bin/view/Main/DCCGraphs	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/bin/view/Main/TWikiAdminGroup	1
# Unknown Location	/twiki/bin/view/Main/TWikiGroups	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/PostfixCommands	1
# Unknown Location	/twiki/bin/view/Main/PostQueue	1
# Unknown Location	/twiki/bin/view/Main/RelayGateway	1
# Unknown Location	/twiki/bin/view/Main/LinksOfUse	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinDeleting	1
# Unknown Location	/twiki/bin/view/Main/PostfixCmd	1
# Unknown Location	/twiki/bin/view/Main/PostSuper	1
# Unknown Location	/twiki/bin/view/Main/RBLsHowTo	1
# Unknown Location	/SpamAssassin.html	1
# Unknown Location	/mailman/listinfo/cncce	1
# Unknown Location	/icons/gnu-head-tiny.jpg	1
# Unknown Location	/icons/mailman.jpg	1
# Unknown Location	/icons/PythonPowered.png	1
# Unknown Location	/AmavisNew.html	1
# Unknown Location	/AmavisNew.html	1
# Unknown Location	/twiki/bin/edit/Main/Double_bounce_sender?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/TWiki/WikiSyntax	1
# Unknown Location	/twiki/bin/view/Main/DCCAndPostFix	1
# Unknown Location	/twiki/bin/oops/TWiki/AppendixFileSystem?template=oopsmore&param1=1.12&param2=1.12	1
# Unknown Location	/twiki/bin/view/Main/PeterThoeny	1
# Unknown Location	/twiki/bin/view/Main/WebChanges	1
# Unknown Location	/twiki/bin/rdiff/Main/WebIndex?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/view/TWiki/DontNotify	1
# Unknown Location	/twiki/bin/view/Main/TokyoOffice	1
# Unknown Location	/twiki/bin/rdiff/Main/ConfigurationVariables	1
# Unknown Location	/twiki/bin/rdiff/Main/NicholasLee	1
# Unknown Location	/twiki/bin/view/Sandbox/WebHome?rev=1.6	1
# Unknown Location	/mailman/listinfo/administration	1
# Unknown Location	/twiki/bin/view/TWiki/ManagingWebs?rev=1.22	1
# Unknown Location	/twiki/bin/statistics/Main	1
# Unknown Location	/twiki/bin/edit/Main/WebSearch?t=1078669682	1
# Unknown Location	/twiki/bin/edit/Main/UvscanAndPostFix?topicparent=Main.WebHome	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassin	1
# Unknown Location	/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Office%20*Locations[^A-Za-z]	1
# Unknown Location	/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.31	1
# Unknown Location	/twiki/bin/view/TWiki/WikiWord?rev=1.3	1
# Unknown Location	/twiki/bin/rdiff/Main/TWikiGuest	1
# Unknown Location	/twiki/bin/edit/Main/TWikiPreferences?topicparent=Main.WebHome	1
# Unknown Location	/twiki/bin/rdiff/TWiki/PeterFokkinga?rev1=1.4&rev2=1.3	1
# Unknown Location	/twiki/bin/view/Main/TWikiGuest	1
# Unknown Location	/twiki/bin/attach/Main/TWikiGroups	1
# Unknown Location	/twiki/bin/rdiff/Main/TWikiGroups?rev1=1.3&rev2=1.2	1
# Unknown Location	/twiki/bin/search/TWiki/?scope=topic&regex=on&search=.*	1
# Unknown Location	/twiki/bin/edit/Main/Trigger_timeout?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^y	1
# Unknown Location	/twiki/bin/edit/Main/Smtpd_history_flush_threshold?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/edit/Main/Sender_canonical_maps?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/mailman/listinfo/mlc	1
# Unknown Location	/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^j	1
# Unknown Location	/twiki/bin/edit/Main/Lmtp_connect_timeout?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/edit/Main/Qmqpd_authorized_clients?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/edit/Main/Header_address_token_limit?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/oops/TWiki/TWikiHistory?template=oopsmore&param1=1.61&param2=1.61	1
# Unknown Location	/twiki/bin/view/TWiki/DefaultPlugin?rev=1.4	1
# Unknown Location	/twiki/bin/rdiff/Main/WebIndex	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiRegistration?rev1=1.10&rev2=1.9	1
# Unknown Location	/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.21	1
# Unknown Location	/twiki/bin/attach/TWiki/DefaultPlugin	1
# Unknown Location	/twiki/bin/rdiff/TWiki/SearchDoesNotWork	1
# Unknown Location	/twiki/bin/rdiff/TWiki/ChangePassword	1
# Unknown Location	/twiki/bin/rdiff/TWiki/SvenDowideit	1
# Unknown Location	/twiki/bin/rdiff/TWiki/KevinKinnell?rev1=1.5&rev2=1.4	1
# Unknown Location	/twiki/bin/edit/Main/Undisclosed_recipients_header?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/attach/TWiki/WebPreferences	1
# Unknown Location	/twiki/bin/rdiff/TWiki/FileAttribute	1
# Unknown Location	/twiki/bin/edit/Main/Mail_release_date?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/attach/Main/ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiHistory?rev=1.8	1
# Unknown Location	/twiki/bin/edit/Sandbox/TestTopic7?topicparent=Sandbox.WebHome	1
# Unknown Location	/twiki/bin/rdiff/Main/VishaalGolam	1
# Unknown Location	/twiki/bin/view/Main/TWikiUsers?rev=1.21	1
# Unknown Location	/twiki/bin/edit/Main/Delay_notice_recipient?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/TWiki/WikiNotation	1
# Unknown Location	/twiki/bin/view/Main/TokyoOffice?rev=1.2	1
# Unknown Location	/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.16	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiHistory?rev1=1.10&rev2=1.9	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Al%20*Williams[^A-Za-z]	1
# Unknown Location	/twiki/bin/edit/Main/Smtpd_banner?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/Main/WebHome?rev=r1.9	1
# Unknown Location	/twiki/bin/view/Know/ReadmeFirst?rev=1.4	1
# Unknown Location	/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.24	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiSiteTools	1
# Unknown Location	/twiki/bin/rdiff/TWiki/RichardDonkin?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/edit/Main/Lmtp_quit_timeout?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/edit/Main/Cleanup_service_name?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/Main/PostSuper?rev=r1.1	1
# Unknown Location	/twiki/bin/edit/TWiki/TablePlugin?t=1078681446	1
# Unknown Location	/twiki/bin/edit/Main/WelcomeGuest?topicparent=Main.WebHome	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiRegistration?rev=r1.7	1
# Unknown Location	/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.26	1
# Unknown Location	/twiki/bin/view/Main/FileAttachment?rev=1.1	1
# Unknown Location	/twiki/bin/oops/Main/NicholasLee?template=oopsmore&param1=1.2&param2=1.2	1
# Unknown Location	/twiki/bin/rdiff/TWiki/DefaultPlugin	1
# Unknown Location	/mailman/private/hsdivision/	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiEnhancementRequests?rev=1.3	1
# Unknown Location	/twiki/bin/view/Main/FileAttachment?rev=1.2	1
# Unknown Location	/twiki/bin/edit/TWiki/AppendixFileSystem?t=1078674582	1
# Unknown Location	/twiki/bin/search/Main/?scope=topic&regex=on&search=^t	1
# Unknown Location	/twiki/bin/edit/TWiki/InterWikis?t=1078696998	1
# Unknown Location	/twiki/bin/view/TWiki/WelcomeGuest?rev=r1.18	1
# Unknown Location	/twiki/bin/edit/TWiki/TWikiPages?topicparent=TWiki.WelcomeGuest	1
# Unknown Location	/twiki/bin/view/Main/WebHome?rev=r1.16	1
# Unknown Location	/twiki/bin/rdiff/TWiki/RyanFreebern?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/edit/Main/Smtp_line_length_limit?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/Main/WebStatistics?skin=print	1
# Unknown Location	/mailman/admin/mlc	1
# Unknown Location	/mailman/listinfo/jjec	1
# Unknown Location	/mailman/listinfo/deans	1
# Unknown Location	/twiki/bin/view/Main/WebNotify	1
# Unknown Location	/twiki/bin/view/Main/WebChanges?skin=print	1
# Unknown Location	/twiki/bin/rdiff/TWiki/IncludeTopicsAndWebPages	1
# Unknown Location	/twiki/bin/oops/Main/WebChanges?template=oopsmore&param1=1.2&param2=1.2	1
# Unknown Location	/twiki/bin/rdiff/TWiki/InstantEnhancements	1
# Unknown Location	/twiki/bin/view/Main/WebHome?rev=r1.24	1
# Unknown Location	/mailman/listinfo/ppwc	1
# Unknown Location	/twiki/bin/view/Main/PostfixCmd	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiSite	1
# Unknown Location	/twiki/bin/rdiff/TWiki/SimultaneousEdits	1
# Unknown Location	/twiki/bin/view/Main/NicholasLee?rev=1.2	1
# Unknown Location	/mailman/listinfo/ncbnpfaculty	1
# Unknown Location	/twiki/bin/oops/TWiki/TextFormattingFAQ?template=oopsmore&param1=1.14&param2=1.14	1
# Unknown Location	/twiki/bin/view/TWiki/WikiName	1
# Unknown Location	/twiki/bin/rdiff/TWiki/SvenDowideit?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/edit/Main/Deliver_lock_attempts?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/edit/Main/Daemon_directory?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/TWiki/DavidWarman	1
# Unknown Location	/twiki/bin/rdiff/Main/PeterThoeny	1
# Unknown Location	/twiki/bin/edit/TWiki/SvenDowideit?t=1078710644	1
# Unknown Location	/twiki/bin/rdiff/TWiki/DefaultPlugin?rev1=1.5&rev2=1.4	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiHistory?rev1=1.61&rev2=1.60	1
# Unknown Location	/mailman/admin/hs_support	1
# Unknown Location	/twiki/bin/edit/Main/Always_bcc?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/TWiki/WelcomeGuest?rev=r1.5	1
# Unknown Location	/twiki/bin/edit/Main/Delay_warning_time?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/attach/Sandbox/WebHome	1
# Unknown Location	/twiki/bin/edit/TWiki/UnchangeableTopicBug?topicparent=TWiki.TWikiHistory	1
# Unknown Location	/twiki/bin/view/Main/TWikiGuest?skin=print	1
# Unknown Location	/twiki/bin/view/TWiki/SvenDowideit?rev=1.1	1
# Unknown Location	/twiki/bin/edit/Main/Maps_rbl_reject_code?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/edit/Main/WebStatistics?t=1078690975	1
# Unknown Location	/twiki/bin/view/Main/RelayGateway?rev=1.3	1
# Unknown Location	/twiki/bin/view/TWiki/WelcomeGuest?rev=r1.11	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Peter%20*Fokkinga[^A-Za-z]	1
# Unknown Location	/mailman/admin/hs_rcafaculty	1
# Unknown Location	/twiki/bin/view/Main/JorisBenschop?skin=print	1
# Unknown Location	/twiki/bin/edit/TWiki/TestArea?topicparent=TWiki.WelcomeGuest	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiSkins?rev1=1.11&rev2=1.10	1
# Unknown Location	/twiki/bin/view/TWiki/DontNotify?rev=1.1	1
# Unknown Location	/twiki/bin/view/TWiki/HaroldGottschalk?rev=1.2	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiHistory?rev=r1.44	1
# Unknown Location	/mailman/listinfo/webct	1
# Unknown Location	/mailman/listinfo/faculty	1
# Unknown Location	/mailman/listinfo/purchasing	1
# Unknown Location	/twiki/bin/rename/TWiki/TWikiHistory	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiHistory?rev=r1.50	1
# Unknown Location	/twiki/bin/edit/TWiki/RyanFreebern?t=1078701457	1
# Unknown Location	/twiki/bin/view/Main/WebPreferences?rev=r1.2	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WebTopicEditTemplate	1
# Unknown Location	/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Web%20*Index[^A-Za-z]	1
# Unknown Location	/twiki/bin/view/TWiki/ChangePassword?rev=r1.6	1
# Unknown Location	/twiki/bin/edit/TWiki/HaroldGottschalk?t=1078717948	1
# Unknown Location	/twiki/bin/edit/Main/Expand_owner_alias?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/Main/WebIndex?rev=r1.2	1
# Unknown Location	/rfc.html	1
# Unknown Location	/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=RBLs%20*How%20*To[^A-Za-z]	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WebTopicEditTemplate?rev1=1.5&rev2=1.4	1
# Unknown Location	/twiki/bin/rdiff/Main/SpamAssassin	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiHistory?rev1=1.8&rev2=1.7	1
# Unknown Location	/twiki/bin/view/TWiki/ChangePassword?rev=r1.3	1
# Unknown Location	/twiki/bin/attach/TWiki/HaroldGottschalk	1
# Unknown Location	/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.15	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiTutorial	1
# Unknown Location	/mailman/private/dentalstudies/	1
# Unknown Location	/twiki/bin/edit/Sandbox/TestTopic6?topicparent=Sandbox.WebHome	1
# Unknown Location	/twiki/bin/view/TWiki/TablePlugin?skin=print	1
# Unknown Location	/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Spam%20*Assassin[^A-Za-z]	1
# Unknown Location	/twiki/bin/view/TWiki/SearchDoesNotWork?rev=r1.1	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=TWiki%20*FAQ[^A-Za-z]	1
# Unknown Location	/twiki/bin/view/Main/SideBar?rev=1.1	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiFAQ	1
# Unknown Location	/twiki/bin/edit/TWiki/WebNotification?topicparent=TWiki.TWikiUpgradeTo01May2000	1
# Unknown Location	/twiki/bin/edit/Main/Export_environment?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/rdiff/Know/ReadmeFirst?rev1=1.6&rev2=1.5	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Change%20*Password[^A-Za-z]	1
# Unknown Location	/twiki/bin/view/TWiki/WebSearch?rev=r1.9	1
# Unknown Location	/twiki/bin/view/Main/TWikiGuest?rev=r1.1	1
# Unknown Location	/twiki/bin/edit/TWiki/TWikiRegistration?t=1078670224	1
# Unknown Location	/twiki/bin/view/Main/TWikiAdminGroup?rev=1.6	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WikiSyntax	1
# Unknown Location	/twiki/bin/oops/TWiki/WikiCulture?template=oopsmore&param1=1.8&param2=1.8	1
# Unknown Location	/twiki/bin/edit/Main/TWikiGuest?t=1078713282	1
# Unknown Location	/twiki/bin/view/Sandbox/WebHome?rev=r1.3	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Wiki%20*Notation[^A-Za-z]	1
# Unknown Location	/twiki/bin/oops/TWiki/WikiNotation?template=oopsmore&param1=1.3&param2=1.3	1
# Unknown Location	/mailman/admin/artsscience	1
# Unknown Location	/twiki/bin/search/Main/?scope=topic&regex=on&search=^d	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiEnhancementRequests	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Kevin%20*Kinnell[^A-Za-z]	1
# Unknown Location	/twiki/bin/view/TWiki/WikiNotation?skin=print	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiPlannedFeatures	1
# Unknown Location	/pipermail/webber/	1
# Unknown Location	/twiki/bin/view/Main/PostSuper?rev=1.1	1
# Unknown Location	/twiki/bin/view/Main/WebPreferences?rev=1.13	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiDocGraphics?rev1=1.11&rev2=1.10	1
# Unknown Location	/twiki/bin/view/TWiki/WebHome?rev=r1.47	1
# Unknown Location	/twiki/bin/view/Sandbox/WebStatistics	1
# Unknown Location	/pipermail/gisgrad/	1
# Unknown Location	/mailman/admin/webber	1
# Unknown Location	/twiki/bin/view/Main/WebPreferences?rev=1.14	1
# Unknown Location	/twiki/bin/view/TWiki/KevinKinnell?rev=1.4	1
# Unknown Location	/twiki/bin/search/Main/?search=\\.*&scope=topic&order=modified&reverse=on&regex=on&nosearch=on&limit=800	1
# Unknown Location	/twiki/bin/view/Main/NicholasLee?rev=1.1	1
# Unknown Location	/twiki/bin/attach/TWiki/TWikiDocGraphics?filename=pencil.gif&revInfo=1	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WebSiteTools?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/rdiff/Main/RelayGateway?rev1=1.3&rev2=1.2	1
# Unknown Location	/twiki/bin/rdiff/Main/RelayGateway?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WikiReferences?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/attach/TWiki/TWikiDocGraphics?filename=viewtopic.gif&revInfo=1	1
# Unknown Location	/twiki/bin/view/TWiki/SvenDowideit?rev=r1.1	1
# Unknown Location	/twiki/bin/edit/Main/Allow_min_user?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/mailman/listinfo/mgt-157	1
# Unknown Location	/mailman/listinfo/cnc_forestry	1
# Unknown Location	/twiki/bin/edit/Main/Strict_8bitmime?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/TWiki/WelcomeGuest?rev=r1.19	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiFAQ?rev=1.11	1
# Unknown Location	/mailman/admin/gisgrad	1
# Unknown Location	/twiki/bin/rdiff/Sandbox/WebTopicList	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Web%20*Topic%20*List[^A-Za-z]	1
# Unknown Location	/twiki/bin/view/TWiki/WebSearch?rev=1.11	1
# Unknown Location	/twiki/bin/view/TWiki/MartinCleaver	1
# Unknown Location	/twiki/bin/edit/Main/TokyoOffice?t=1078706364	1
# Unknown Location	/twiki/bin/rdiff/Main/SpamAssassinAndPostFix?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/rdiff/Main/WebChanges?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/search/Main/?scope=topic&regex=on&search=^f	1
# Unknown Location	/RBL.html	1
# Unknown Location	/twiki/bin/rdiff/TWiki/NewUserTemplate?rev1=1.3&rev2=1.2	1
# Unknown Location	/mailman/listinfo/hsdivision	1
# Unknown Location	/twiki/bin/edit/Main/Header_checks?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/attach/Main/OfficeLocations	1
# Unknown Location	/twiki/bin/view/TWiki/WebTopicEditTemplate	1
# Unknown Location	/twiki/bin/edit/Main/Smtpd_etrn_restrictions?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/mailman/listinfo/business	1
# Unknown Location	/twiki/bin/view/Main/MikeMannix	1
# Unknown Location	/twiki/bin/attach/Main/PostfixCommands	1
# Unknown Location	/twiki/bin/rdiff/Know/ReadmeFirst?rev1=1.5&rev2=1.4	1
# Unknown Location	/twiki/bin/view/Main/TWikiGroups?rev=1.2	1
# Unknown Location	/twiki/bin/edit/Main/Flush_service_name?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiRegistration	1
# Unknown Location	/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Joris%20*Benschop[^A-Za-z]	1
# Unknown Location	/twiki/bin/oops/TWiki/TextFormattingRules?template=oopsmore&param1=1.37&param2=1.37	1
# Unknown Location	/twiki/bin/edit/TWiki/DefaultPlugin?t=1078688936	1
# Unknown Location	/twiki/bin/search/Main/?scope=topic&regex=on&search=^g	1
# Unknown Location	/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^d	1
# Unknown Location	/twiki/bin/attach/TWiki/TablePlugin	1
# Unknown Location	/twiki/bin/view/TWiki/WikiCulture	1
# Unknown Location	/twiki/bin/oops/TWiki/ResetPassword?template=oopsmore&param1=1.4&param2=1.4	1
# Unknown Location	/twiki/bin/view/TWiki/ManagingWebs?skin=print	1
# Unknown Location	/twiki/bin/view/TWiki/KlausWriessnegger	1
# Unknown Location	/twiki/bin/oops/TWiki/RichardDonkin?template=oopsmore&param1=1.2&param2=1.2	1
# Unknown Location	/twiki/bin/rdiff/TWiki/AlWilliams?rev1=1.3&rev2=1.2	1
# Unknown Location	/twiki/bin/rdiff/TWiki/AlWilliams?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/view/TWiki/SvenDowideit	1
# ...
# Unknown Location	/twiki/bin/view/TWiki/WikiReferences?skin=print	1
# Unknown Location	/twiki/bin/view/Main/TokyoOffice?rev=1.3	1
# Unknown Location	/twiki/bin/rdiff/Main/PostQueue	1
# Unknown Location	/twiki/bin/oops/Sandbox/WebHome?template=oopsmore&param1=1.7&param2=1.7	1
# Unknown Location	/twiki/bin/view/TWiki/RichardDonkin?skin=print	1
# Unknown Location	/twiki/bin/view/Main/WebPreferences?rev=r1.4	1
# Unknown Location	/twiki/bin/view/TWiki/GoBox	1
# Unknown Location	/twiki/bin/attach/TWiki/KevinKinnell	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WikiWikiClones	1
# Unknown Location	/twiki/bin/edit/Main/TWikiForms?topicparent=Main.TWikiVariables	1
# Unknown Location	/mailman/admin/educationadmin	1
# Unknown Location	/mailman/listinfo/artsscience	1
# Unknown Location	/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^i	1
# Unknown Location	/twiki/bin/rdiff/TWiki/AdrianLynch	1
# Unknown Location	/twiki/bin/view/Main/WelcomeGuest	1
# Unknown Location	/twiki/bin/view/Main/MikeMannix?rev=1.3	1
# Unknown Location	/twiki/bin/edit/TWiki/WikiStyleWord?topicparent=TWiki.TextFormattingFAQ	1
# Unknown Location	/twiki/bin/view/TWiki/FormattedSearch?rev=1.8	1
# Unknown Location	/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.33	1
# Unknown Location	/twiki/bin/oops/TWiki/TWikiPlugins?template=oopsmore&param1=1.21&param2=1.21	1
# Unknown Location	/mailman/private/sswk/	1
# Unknown Location	/mailman/private/business/	1
# Unknown Location	/twiki/bin/search/TWiki/?search=\\.*&scope=topic&order=modified&reverse=on&regex=on&nosearch=on&limit=200	1
# Unknown Location	/mailman/listinfo/webber	1
# Unknown Location	/mailman/listinfo/gisgrad	1
# Unknown Location	/twiki/bin/edit/Main/Setgid_group?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiPreferences?rev1=1.47&rev2=1.46	1
# Unknown Location	/twiki/bin/search/TWiki/?scope=topic&regex=on&bookview=on&search=.*	1
# Unknown Location	/twiki/bin/edit/Main/Local_recipient_maps?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/mailman/listinfo	1
# Unknown Location	/twiki/bin/edit/TWiki/NewTopic?topicparent=TWiki.WikiSyntax	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiHistory?rev=1.9	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Inter%20*Wikis[^A-Za-z]	1
# Unknown Location	/twiki/bin/rdiff/Main/WebTopicList	1
# Unknown Location	/ie.htm	1
# Unknown Location	/mailman/private/mlc/	1
# Unknown Location	/twiki/bin/rdiff/Main/WebRss	1
# Unknown Location	/twiki/bin/rdiff/TWiki/KlausWriessnegger?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/view/Main/TWikiGuest?rev=1.4	1
# Unknown Location	/twiki/bin/edit/Main/Relayhost?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/edit/Main/BookView?topicparent=Main.TWikiVariables	1
# Unknown Location	/twiki/bin/rdiff/TWiki/DeleteOrRenameATopic	1
# Unknown Location	/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.28	1
# Unknown Location	/twiki/bin/edit/Main/RBLsHowTo?t=1078668449	1
# Unknown Location	/twiki/bin/rdiff/Main/TWikiGuest?rev1=1.5&rev2=1.4	1
# Unknown Location	/twiki/bin/edit/TWiki/KlausWriessnegger?t=1078709735	1
# Unknown Location	/twiki/bin/rdiff/TWiki/StanleyKnutson	1
# Unknown Location	/twiki/bin/view/TWiki/WhatIsWikiWiki	1
# Unknown Location	/twiki/bin/view/Main/WebIndex?rev=1.1	1
# Unknown Location	/mailman/private/hs_support/	1
# Unknown Location	/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Web%20*Changes[^A-Za-z]	1
# Unknown Location	/twiki/bin/rdiff/TWiki/KevinKinnell?rev1=1.4&rev2=1.3	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiRegistration?rev=r1.4	1
# Unknown Location	/twiki/bin/edit/TWiki/TWikiCodevTWikiEnhancementRequests?topicparent=TWiki.TWikiHistory	1
# Unknown Location	/twiki/bin/attach/Main/WebPreferences	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WebChanges	1
# Unknown Location	/twiki/bin/view/TWiki/WelcomeGuest?rev=r1.6	1
# Unknown Location	/twiki/bin/rdiff/TWiki/HaroldGottschalk?rev1=1.2&rev2=1.1	1
# Unknown Location	/pipermail/techcomm/	1
# Unknown Location	/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.19	1
# Unknown Location	/twiki/bin/edit/Sandbox/TestTopic2?topicparent=Sandbox.WebHome	1
# Unknown Location	/twiki/bin/attach/TWiki/InterWikis	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WebNotify	1
# Unknown Location	/twiki/bin/edit/Main/Masquerade_classes?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/Main/WebPreferences?rev=r1.10	1
# Unknown Location	/twiki/bin/edit/TWiki/TWikiCodevTWikiPlannedFeatures?topicparent=TWiki.TWikiHistory	1
# Unknown Location	/twiki/bin/view/TWiki/PeterFokkinga?rev=1.2	1
# Unknown Location	/twiki/bin/edit/TWiki/TWikiPlugins?t=1078696313	1
# Unknown Location	/razor.html	1
# Unknown Location	/mailman/admin/sswk	1
# Unknown Location	/twiki/bin/edit/Main/Invalid_hostname_reject_code?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/rdiff/Main/WebPreferences?rev1=1.14&rev2=1.13	1
# Unknown Location	/twiki/bin/view/TWiki/SearchDoesNotWork?rev=r1.2	1
# Unknown Location	/twiki/bin/edit/Main/Unknown_local_recipient_reject_code?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/SpamAssassin.html	1
# Unknown Location	/twiki/bin/rdiff/Main/TokyoOffice?rev1=1.2&rev2=1.1	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiCategoryTable	1
# Unknown Location	/twiki/bin/view/Main/WebPreferences?rev=r1.14	1
# Unknown Location	/LateEmail.html	1
# Unknown Location	/dccstats/index.html	1
# Unknown Location	/twiki/bin/view/TWiki/WebSearch?rev=r1.10	1
# Unknown Location	/twiki/bin/rdiff/TWiki/TWikiDownload	1
# Unknown Location	/twiki/bin/view/Main/TWikiGuest?rev=r1.3	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiTopics?rev=r1.4	1
# Unknown Location	/twiki/bin/rename/TWiki/DefaultPlugin	1
# Unknown Location	/twiki/bin/view/TWiki/WikiTopic	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WebPreferences	1
# Unknown Location	/twiki/bin/view/TWiki/WebSearch?skin=print	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiTopics?rev=r1.7	1
# Unknown Location	/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Thanadon%20*Somdee[^A-Za-z]	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiUpgradeTo01May2000?rev=1.3	1
# Unknown Location	/twiki/bin/edit/Main/Max_use?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WebRss	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WikiCulture?rev1=1.8&rev2=1.7	1
# Unknown Location	/twiki/bin/edit/Main/Lmtp_mail_timeout?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/rdiff/TWiki/AdminSkillsAssumptions	1
# Unknown Location	/twiki/bin/edit/TWiki/WikiNotation?t=1078726052	1
# Unknown Location	/twiki/bin/edit/TWiki/TWikiCodevFeatureToDo?topicparent=TWiki.TWikiHistory	1
# Unknown Location	/twiki/bin/rename/TWiki/ResetPassword	1
# Unknown Location	/twiki/bin/edit/Main/Fast_flush_domains?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/edit/Main/SpamAssassin?t=1078709979	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiTopics?rev=r1.10	1
# Unknown Location	/twiki/bin/view/TWiki/FileAttribute?rev=r1.2	1
# Unknown Location	/twiki/bin/view/TWiki/FileAttribute?rev=1.2	1
# Unknown Location	/mailman/admin/deans	1
# Unknown Location	/twiki/bin/edit/Main/Mailq_path?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/TWiki/WebHome?rev=r1.49	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiHistory?rev=r1.49	1
# Unknown Location	/twiki/bin/oops/TWiki/HaroldGottschalk?template=oopsmore&param1=1.3&param2=1.3	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=John%20*Talintyre[^A-Za-z]	1
# Unknown Location	/twiki/bin/attach/Main/TWikiGuest	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiHistory?rev=r1.55	1
# Unknown Location	/twiki/bin/attach/Main/SpamAssassinAndPostFix	1
# Unknown Location	/mailman/private/artsscience/	1
# Unknown Location	/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^l	1
# Unknown Location	/twiki/bin/view/Main/WebPreferences?rev=r1.9	1
# Unknown Location	/twiki/bin/edit/TWiki/WebSiteTools?t=1078731408	1
# Unknown Location	/twiki/bin/edit/Main/Ignore_mx_lookup_error?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/oops/Main/DCCAndPostFix?template=oopsmore&param1=1.2&param2=1.2	1
# Unknown Location	/twiki/bin/view/TWiki/TWikiHistory?rev=r1.54	1
# Unknown Location	/twiki/bin/edit/TWiki/KevinKinnell?t=1078692967	1
# Unknown Location	/pipermail/fcd/	1
# Unknown Location	/mailman/admin/fcd	1
# Unknown Location	/mailman/admin/jjec	1
# Unknown Location	/twiki/bin/oops/TWiki/RyanFreebern?template=oopsmore&param1=1.2&param2=1.2	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WebChangesAlert	1
# Unknown Location	/twiki/bin/edit/Main/Virtual_gid_maps?topicparent=Main.ConfigurationVariables	1
# Unknown Location	/twiki/bin/view/TWiki/NewUserTemplate?skin=print	1
# Unknown Location	/mailman/admin	1
# Unknown Location	/mailman/admin/ncbnpfaculty	1
# Unknown Location	/twiki/bin/view/TWiki/WebIndex	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WhatIsWikiWiki	1
# Unknown Location	/twiki/bin/rdiff/TWiki/EditDoesNotIncreaseTheRevision	1
# Unknown Location	/twiki/bin/rdiff/TWiki/WebTopicList	1
# Unknown Location	/antivirus.html	1
# Unknown Location	/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Harold%20*Gottschalk[^A-Za-z]	1
# Unknown Location	/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.37	1
# Unknown Location	/	1
# Unknown Location	/twiki/bin/view/Main/DCCAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC	1
# Unknown Location	/twiki/bin/view/Main/PostfixCmd	1
# Unknown Location	/twiki/bin/view/Main/PostSuper	1
# Unknown Location	/twiki/bin/view/Main/SideBar	1
# Unknown Location	/twiki/bin/view/Main/DCCGraphs	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinDeleting	1
# Unknown Location	/twiki/bin/view/Main/PostfixCommands	1
# Unknown Location	/SpamAssassin.html	1
# Unknown Location	/	1
# Unknown Location	/	1
# Unknown Location	/dccstats/stats-spam-ratio.1day.png	1
# Unknown Location	/dccstats/stats-hashes.1week.png	1
# Unknown Location	/dccstats/stats-spam.1month.png	1
# Unknown Location	/dccstats/stats-hashes.1month.png	1
# Unknown Location	/dccstats/stats-spam.1year.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1year.png	1
# Unknown Location	/dccstats/stats-hashes.1year.png	1
# Unknown Location	/DCC.html	1
# Unknown Location	/twiki/bin/view/Main/DCC	1
# Unknown Location	/twiki/bin/view/Main/DCCAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/PostfixCmd	1
# Unknown Location	/twiki/pub/TWiki/TWikiDocGraphics/help.gif	1
# Unknown Location	/twiki/bin/view/Main/PostSuper	1
# Unknown Location	/twiki/bin/view/Main/VerifingGatway	1
# Unknown Location	/razor.html	1
# Unknown Location	/dccstats/index.html	1
# Unknown Location	/dccstats/stats-spam.1day.png	1
# Unknown Location	/dccstats/stats-spam.1week.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1week.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1month.png	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/PostfixCommands	1
# Unknown Location	/twiki/bin/edit/Main/PostConf?topicparent=Main.PostfixCommands	1
# Unknown Location	/twiki/bin/view/Main/RelayGateway	1
# Unknown Location	/twiki/bin/view/Main/Relay_Domains	1
# Unknown Location	/favicon.ico	1
# Unknown Location	/razor.html	1
# Unknown Location	/favicon.ico	1
# Unknown Location	/twiki/bin/view/Main/DCCAndPostFix	1
# Unknown Location	/twiki/pub/TWiki/TWikiDocGraphics/help.gif	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/KevinWGagel	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinDeleting	1
# Unknown Location	/twiki/bin/edit/Main/RazorAndPostFix?topicparent=Main.WebHome	1
# Unknown Location	/twiki/bin/view/Main/RelayGateway	1
# Unknown Location	/twiki/bin/view/Main/LinksOfUse	1
# Unknown Location	/AmavisNew.html	1
# Unknown Location	/	1
# Unknown Location	/dccstats/stats-spam-ratio.1day.png	1
# Unknown Location	/dccstats/stats-hashes.1week.png	1
# Unknown Location	/dccstats/stats-spam.1month.png	1
# Unknown Location	/dccstats/stats-hashes.1month.png	1
# Unknown Location	/dccstats/stats-spam.1year.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1year.png	1
# Unknown Location	/dccstats/stats-hashes.1year.png	1
# Unknown Location	/cgi-bin/mailgraph.cgi/mailgraph_0_err.png	1
# Unknown Location	/cgi-bin/mailgraph.cgi/mailgraph_2.png	1
# Unknown Location	/cgi-bin/mailgraph.cgi/mailgraph_2_err.png	1
# Unknown Location	/cgi-bin/mailgraph.cgi/mailgraph_3.png	1
# Unknown Location	/cgi-bin/mailgraph.cgi/mailgraph_3_err.png	1
# Unknown Location	/dccstats/index.html	1
# Unknown Location	/dccstats/stats-spam.1day.png	1
# Unknown Location	/dccstats/stats-spam.1week.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1week.png	1
# Unknown Location	/dccstats/stats-spam-ratio.1month.png	1
# Unknown Location	/cgi-bin/mailgraph2.cgi	1
# Unknown Location	/cgi-bin/mailgraph.cgi/mailgraph_0.png	1
# Unknown Location	/cgi-bin/mailgraph.cgi/mailgraph_1.png	1
# Unknown Location	/cgi-bin/mailgraph.cgi/mailgraph_1_err.png	1
# Unknown Location	/razor.html	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinDeleting	1
# Unknown Location	/	1
# Unknown Location	/twiki/bin/view/Main/RBLsHowTo	1
# Unknown Location	/twiki/pub/TWiki/TWikiDocGraphics/help.gif	1
# Unknown Location	/twiki/bin/view/Main/VerifingGatway	1
# Unknown Location	/twiki/bin/view/Main/SideBar	1
# Unknown Location	/twiki/bin/view/Main/DCCAndPostFix	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinAndPostFix	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinTaggingOnly	1
# Unknown Location	/twiki/bin/view/Main/PostfixCommands	1
# Unknown Location	/twiki/bin/edit/Main/PostConf?topicparent=Main.PostfixCommands	1
# Unknown Location	/twiki/bin/view/Main/RelayGateway	1
# Unknown Location	/twiki/bin/view/Main/Relay_Domains	1
# Unknown Location	/AmavisNew.html	1
# Unknown Location	/AmavisNew.html	1
# Unknown Location	/twiki/bin/view/Main/RBLsHowTo	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/images/image004.jpg	1
# Unknown Location	/ie.htm	1
# Unknown Location	/images/image005.jpg	1
# Unknown Location	/images/msgops.JPG	1
# Unknown Location	/pipermail/webber/2004-January/000000.html	1
# Unknown Location	/razor.html	1
# Unknown Location	/razor.html	1
# Unknown Location	/twiki/bin/view/Main/SpamAssassinDeleting	1
# Unknown Location	/pipermail/cipg/2003-november.txt	1
# Unknown Location	/razor.html	1
# Unknown Location	/twiki/bin/view/Main/WebHome	1
# Unknown Location	/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif	1
# Unknown Location	/twiki/bin/view/Main/LinksOfUse	1
# Wherever You Want to Ship	/dccstats/index.html	1
# Wherever You Want to Ship	/dccstats/stats-spam.1day.png	1
# Wherever You Want to Ship	/dccstats/stats-spam-ratio.1week.png	1
# Wherever You Want to Ship	/dccstats/stats-spam.1week.png	1
# Wherever You Want to Ship	/dccstats/stats-spam-ratio.1month.png	1
# Wherever You Want to Ship	/	1
# Wherever You Want to Ship	/dccstats/stats-spam-ratio.1day.png	1
# Wherever You Want to Ship	/dccstats/stats-hashes.1week.png	1
# Wherever You Want to Ship	/dccstats/stats-spam.1month.png	1
# Wherever You Want to Ship	/dccstats/stats-hashes.1month.png	1
# Wherever You Want to Ship	/dccstats/stats-spam.1year.png	1
# Wherever You Want to Ship	/dccstats/stats-spam-ratio.1year.png	1
# Wherever You Want to Ship	/dccstats/stats-hashes.1year.png	1

# %% [markdown]
# # (B) DataFrame Implementations
#
# Perform reporting tasks 1 and 2 using Spark's DataFrame API. Note that you should *not* use the Spark SQL abstraction.

# %%
# DataFrame implementation
# (1) Given an Apache HTTP access log, along with a CSV file that includes country information for
# hostnames (sample file: [hostname_country.csv](https://cpslo-my.sharepoint.com/:x:/g/personal/amigler_calpoly_edu/EcJv6-ZtZR5PpTEcKuDcYmsBq38YIwrNL6d6JtVztjrkhA?e=xTmRdh)),
# produce a report that shows the total request count for each country, sorted by request count (highest to lowest)

access_log_df = spark.read.options(delimiter=" ").csv("apache.access.log")

access_log_df = access_log_df.select(col('_c0').alias('hostname'),
                                col('_c3').alias('timestamp'),
                                col('_c5').alias('path'),
                                col('_c6').cast('integer').alias('status'),
                                col('_c7').cast('integer').alias('content_size'))
hostname_country_df = spark.read.csv("hostname_country.csv")

hostname_country_df = hostname_country_df.select(col('_c0').alias('hostname'),
                                                 col('_c1').alias('country'))

joined_df = access_log_df.join(hostname_country_df,
                               access_log_df['hostname'] == hostname_country_df['hostname'],
                               how='left_outer')

count_df = joined_df.groupBy('country').count().orderBy('count', ascending=False)

count_df.show(truncate=False)
# Out:
# +-------------------------+-----+
# |country                  |count|
# +-------------------------+-----+
# |Unknown Location         |812  |
# |Intranet                 |198  |
# |Canada                   |127  |
# |United States            |87   |
# |Robot                    |80   |
# |Israel                   |19   |
# |Australia                |17   |
# |France                   |16   |
# |Germany                  |13   |
# |Wherever You Want to Ship|13   |
# |United Kingdom           |6    |
# |Spain                    |4    |
# |Denmark                  |4    |
# |Korea                    |4    |
# |Netherlands              |2    |
# |Taiwan                   |1    |
# |Finland                  |1    |
# |Mexico                   |1    |
# |Los Alamos               |1    |
# +-------------------------+-----+

# %%
# DataFrame implementation
# (2) Using the same two input files (access.log and hostname_country.csv), produce a report that lists,
# for each country, the count of each URL visited. Sort by country (alphabetically, A-Z) then count (from highest to lowest)

access_log_df = spark.read.options(delimiter=" ").csv("apache.access.log")

access_log_df = access_log_df.select(col('_c0').alias('hostname'),
                                col('_c3').alias('timestamp'),
                                col('_c5').alias('path'),
                                col('_c6').cast('integer').alias('status'),
                                col('_c7').cast('integer').alias('content_size'))

hostname_country_df = spark.read.csv("hostname_country.csv")

hostname_country_df = hostname_country_df.select(col('_c0').alias('hostname'),
                                                 col('_c1').alias('country'))

joined_df = access_log_df.join(hostname_country_df, access_log_df['hostname'] == hostname_country_df['hostname'], 'left_outer')

count_df = joined_df.groupBy('country', 'path').count().orderBy(['country', 'count'], ascending=[True, False])

count_df.show(count_df.count(), truncate=False)
# Out:
# +-------------------------+------------------------------------------------------------------------------------------------------------------------+-----+
# |country                  |path                                                                                                                    |count|
# +-------------------------+------------------------------------------------------------------------------------------------------------------------+-----+
# |Australia                |GET /mailman/listinfo HTTP/1.1                                                                                          |2    |
# |Australia                |GET /twiki/bin/view/Main/SpamAssassinAndPostFix HTTP/1.1                                                                |2    |
# |Australia                |GET /twiki/bin/view/Main/SpamAssassinDeleting HTTP/1.1                                                                  |2    |
# |Australia                |GET /icons/gnu-head-tiny.jpg HTTP/1.1                                                                                   |1    |
# |Australia                |GET /twiki/bin/view/Main/WebHome HTTP/1.1                                                                               |1    |
# |Australia                |GET /mailman/listinfo/cnc_notice HTTP/1.1                                                                               |1    |
# |Australia                |GET /mailman/admin HTTP/1.1                                                                                             |1    |
# |Australia                |GET /mailman/listinfo/administration HTTP/1.1                                                                           |1    |
# |Australia                |GET /icons/PythonPowered.png HTTP/1.1                                                                                   |1    |
# |Australia                |GET /mailman/admin/webct HTTP/1.1                                                                                       |1    |
# |Australia                |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif HTTP/1.1                                                            |1    |
# |Australia                |GET /icons/mailman.jpg HTTP/1.1                                                                                         |1    |
# |Australia                |GET /twiki/bin/view/Main/SpamAssassinTaggingOnly HTTP/1.1                                                               |1    |
# |Australia                |GET /mailman HTTP/1.1                                                                                                   |1    |
# |Canada                   |GET /mailman/listinfo/ppwc HTTP/1.1                                                                                     |9    |
# |Canada                   |GET /mailman/listinfo HTTP/1.1                                                                                          |6    |
# |Canada                   |GET /icons/gnu-head-tiny.jpg HTTP/1.1                                                                                   |5    |
# |Canada                   |GET /ie.htm HTTP/1.1                                                                                                    |5    |
# |Canada                   |GET /images/image005.jpg HTTP/1.1                                                                                       |5    |
# |Canada                   |GET /icons/mailman.jpg HTTP/1.1                                                                                         |5    |
# |Canada                   |GET /images/image004.jpg HTTP/1.1                                                                                       |5    |
# |Canada                   |GET /images/msgops.JPG HTTP/1.1                                                                                         |5    |
# |Canada                   |POST /mailman/admin/ppwc HTTP/1.1                                                                                       |5    |
# |Canada                   |GET /icons/PythonPowered.png HTTP/1.1                                                                                   |5    |
# |Canada                   |GET / HTTP/1.1                                                                                                          |4    |
# |Canada                   |GET /mailman/admin/ppwc HTTP/1.1                                                                                        |4    |
# |Canada                   |GET /mailman HTTP/1.1                                                                                                   |3    |
# |Canada                   |GET /cgi-bin/mailgraph.cgi/mailgraph_2_err.png HTTP/1.1                                                                 |2    |
# |Canada                   |POST /mailman/options/cnc_notice HTTP/1.1                                                                               |2    |
# |Canada                   |GET /cgi-bin/mailgraph.cgi/mailgraph_3.png HTTP/1.1                                                                     |2    |
# |Canada                   |GET /cgi-bin/mailgraph.cgi/mailgraph_3_err.png HTTP/1.1                                                                 |2    |
# |Canada                   |GET /cgi-bin/mailgraph.cgi/mailgraph_1.png HTTP/1.1                                                                     |2    |
# |Canada                   |GET /mailman/admin/ppwc/gateway HTTP/1.1                                                                                |2    |
# |Canada                   |GET /cgi-bin/mailgraph.cgi/mailgraph_1_err.png HTTP/1.1                                                                 |2    |
# |Canada                   |POST /mailman/admindb/ppwc HTTP/1.1                                                                                     |2    |
# |Canada                   |GET /cgi-bin/mailgraph.cgi/mailgraph_0_err.png HTTP/1.1                                                                 |2    |
# |Canada                   |GET /favicon.ico HTTP/1.1                                                                                               |2    |
# |Canada                   |GET /cgi-bin/mailgraph.cgi/mailgraph_0.png HTTP/1.1                                                                     |2    |
# |Canada                   |GET /cgi-bin/mailgraph.cgi/mailgraph_2.png HTTP/1.1                                                                     |2    |
# |Canada                   |GET /cgi-bin/mailgraph2.cgi HTTP/1.1                                                                                    |2    |
# |Canada                   |GET /LateEmail.html HTTP/1.1                                                                                            |1    |
# |Canada                   |GET /pipermail/cncce/2004-January/000001.html HTTP/1.1                                                                  |1    |
# |Canada                   |GET /pipermail/cnc_notice/2003-December/000002.html HTTP/1.1                                                            |1    |
# |Canada                   |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif HTTP/1.1                                                            |1    |
# |Canada                   |GET /dccstats/stats-hashes.1week.png HTTP/1.1                                                                           |1    |
# |Canada                   |GET /mailman/admin/ppwc/members HTTP/1.1                                                                                |1    |
# |Canada                   |GET /dccstats/stats-spam-ratio.1year.png HTTP/1.1                                                                       |1    |
# |Canada                   |GET /mailman/admin/ppwc/general HTTP/1.1                                                                                |1    |
# |Canada                   |GET /mailman/admin/ppwc/members?letter=p HTTP/1.1                                                                       |1    |
# |Canada                   |GET /mailman/admindb/ppwc HTTP/1.1                                                                                      |1    |
# |Canada                   |GET /pipermail/cnc_notice/2003-December.txt HTTP/1.1                                                                    |1    |
# |Canada                   |GET /mailman/admin/ppwc/members?letter=n HTTP/1.1                                                                       |1    |
# |Canada                   |GET /dccstats/stats-spam.1year.png HTTP/1.1                                                                             |1    |
# |Canada                   |GET /dccstats/stats-hashes.1year.png HTTP/1.1                                                                           |1    |
# |Canada                   |GET /twiki/bin/view/Main/KevinWGagel HTTP/1.1                                                                           |1    |
# |Canada                   |GET /twiki/view/Main/WebHome HTTP/1.1                                                                                   |1    |
# |Canada                   |GET /twiki/bin/view/Main/WebHome HTTP/1.1                                                                               |1    |
# |Canada                   |GET /dccstats/index.html HTTP/1.1                                                                                       |1    |
# |Canada                   |GET /dccstats/stats-hashes.1month.png HTTP/1.1                                                                          |1    |
# |Canada                   |GET /twiki/bin/view/Main/TWikiUsers HTTP/1.1                                                                            |1    |
# |Canada                   |GET /RBL.html HTTP/1.1                                                                                                  |1    |
# |Canada                   |GET /twiki/ HTTP/1.1                                                                                                    |1    |
# |Canada                   |GET /mailman/admin/ppwc/?VARHELP=general/owner HTTP/1.1                                                                 |1    |
# |Canada                   |GET /dccstats/stats-spam.1week.png HTTP/1.1                                                                             |1    |
# |Canada                   |GET /dccstats/stats-spam-ratio.1month.png HTTP/1.1                                                                      |1    |
# |Canada                   |GET /dccstats/stats-spam.1day.png HTTP/1.1                                                                              |1    |
# |Canada                   |GET /mailman/admin/ppwc/passwords HTTP/1.1                                                                              |1    |
# |Canada                   |GET /dccstats/stats-spam-ratio.1week.png HTTP/1.1                                                                       |1    |
# |Canada                   |GET /mailman/options/cnc_notice/arobin%40shaw.c HTTP/1.1                                                                |1    |
# |Canada                   |GET /pipermail/cnc_notice/2004-February.txt HTTP/1.1                                                                    |1    |
# |Canada                   |GET /SpamAssassin.html HTTP/1.1                                                                                         |1    |
# |Canada                   |GET /mailman/admin/ppwc/logout HTTP/1.1                                                                                 |1    |
# |Canada                   |GET /mailman/listinfo/administration HTTP/1.1                                                                           |1    |
# |Canada                   |GET /dccstats/stats-spam-ratio.1day.png HTTP/1.1                                                                        |1    |
# |Canada                   |GET /dccstats/stats-spam.1month.png HTTP/1.1                                                                            |1    |
# |Denmark                  |GET /razor.html HTTP/1.1                                                                                                |1    |
# |Denmark                  |GET /favicon.ico HTTP/1.1                                                                                               |1    |
# |Denmark                  |GET /twiki/bin/view/Main/WebHome HTTP/1.0                                                                               |1    |
# |Denmark                  |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif HTTP/1.0                                                            |1    |
# |Finland                  |GET /razor.html HTTP/1.1                                                                                                |1    |
# |France                   |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot88x31.gif HTTP/1.1                                                            |1    |
# |France                   |GET /twiki/bin/view/Main/WebHome HTTP/1.1                                                                               |1    |
# |France                   |GET /twiki/bin/view/Main/SpamAssassinAndPostFix HTTP/1.1                                                                |1    |
# |France                   |GET / HTTP/1.1                                                                                                          |1    |
# |France                   |GET /twiki/bin/view/Main/ConfigurationVariables HTTP/1.1                                                                |1    |
# |France                   |GET /twiki/bin/view/Main/DCCAndPostFix HTTP/1.1                                                                         |1    |
# |France                   |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif HTTP/1.1                                                            |1    |
# |France                   |GET /twiki/bin/view/Sandbox/WebHome HTTP/1.1                                                                            |1    |
# |France                   |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot131x64.gif HTTP/1.1                                                           |1    |
# |France                   |GET /twiki/bin/view/Main/SpamAssassinDeleting HTTP/1.1                                                                  |1    |
# |France                   |GET /twiki/bin/view/Main/SpamAssassinTaggingOnly HTTP/1.1                                                               |1    |
# |France                   |GET /twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC HTTP/1.1                                                          |1    |
# |France                   |GET /twiki/bin/view/Main/SpamAssassin HTTP/1.1                                                                          |1    |
# |France                   |GET /twiki/pub/TWiki/TWikiDocGraphics/tip.gif HTTP/1.1                                                                  |1    |
# |France                   |GET /twiki/bin/view/TWiki/WebHome HTTP/1.1                                                                              |1    |
# |France                   |GET /razor.html HTTP/1.1                                                                                                |1    |
# |Germany                  |GET /twiki/bin/view/Main/WebHome HTTP/1.1                                                                               |2    |
# |Germany                  |GET /favicon.ico HTTP/1.1                                                                                               |1    |
# |Germany                  |GET /SpamAssassin.html HTTP/1.0                                                                                         |1    |
# |Germany                  |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif HTTP/1.1                                                            |1    |
# |Germany                  |GET /twiki/bin/view/Main/Postfix HTTP/1.1                                                                               |1    |
# |Germany                  |GET /twiki/bin/view/Main/SpamAssassinDeleting HTTP/1.1                                                                  |1    |
# |Germany                  |GET /twiki/bin/view/Main/SpamAssassinTaggingOnly HTTP/1.1                                                               |1    |
# |Germany                  |GET /twiki/bin/edit/Main/UvscanAndPostFix?topicparent=Main.WebHome HTTP/1.1                                             |1    |
# |Germany                  |GET /twiki/bin/view/Main/SpamAssassinAndPostFix HTTP/1.1                                                                |1    |
# |Germany                  |GET /twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC HTTP/1.1                                                          |1    |
# |Germany                  |GET /twiki/bin/view/Main/DCCAndPostFix HTTP/1.1                                                                         |1    |
# |Germany                  |GET /twiki/pub/TWiki/TWikiDocGraphics/help.gif HTTP/1.1                                                                 |1    |
# |Intranet                 |GET /cgi-bin/mailgraph.cgi/mailgraph_1.png HTTP/1.1                                                                     |13   |
# |Intranet                 |GET /cgi-bin/mailgraph.cgi/mailgraph_3.png HTTP/1.1                                                                     |13   |
# |Intranet                 |GET /cgi-bin/mailgraph.cgi/mailgraph_1_err.png HTTP/1.1                                                                 |13   |
# |Intranet                 |GET /cgi-bin/mailgraph.cgi/mailgraph_0_err.png HTTP/1.1                                                                 |13   |
# |Intranet                 |GET /cgi-bin/mailgraph.cgi/mailgraph_0.png HTTP/1.1                                                                     |13   |
# |Intranet                 |GET /cgi-bin/mailgraph.cgi/mailgraph_3_err.png HTTP/1.1                                                                 |13   |
# |Intranet                 |GET /cgi-bin/mailgraph.cgi/mailgraph_2.png HTTP/1.1                                                                     |13   |
# |Intranet                 |GET /cgi-bin/mailgraph.cgi/mailgraph_2_err.png HTTP/1.1                                                                 |13   |
# |Intranet                 |GET /cgi-bin/mailgraph2.cgi HTTP/1.1                                                                                    |13   |
# |Intranet                 |GET /dccstats/stats-spam.1day.png HTTP/1.1                                                                              |5    |
# |Intranet                 |GET /dccstats/stats-hashes.1year.png HTTP/1.1                                                                           |5    |
# |Intranet                 |GET /dccstats/stats-spam.1week.png HTTP/1.1                                                                             |5    |
# |Intranet                 |GET /dccstats/stats-spam-ratio.1year.png HTTP/1.1                                                                       |5    |
# |Intranet                 |GET /dccstats/stats-hashes.1month.png HTTP/1.1                                                                          |5    |
# |Intranet                 |GET /dccstats/stats-spam-ratio.1month.png HTTP/1.1                                                                      |5    |
# |Intranet                 |GET /dccstats/stats-spam.1year.png HTTP/1.1                                                                             |5    |
# |Intranet                 |GET /dccstats/stats-spam-ratio.1week.png HTTP/1.1                                                                       |5    |
# |Intranet                 |GET /dccstats/stats-spam.1month.png HTTP/1.1                                                                            |5    |
# |Intranet                 |GET /dccstats/stats-spam-ratio.1day.png HTTP/1.1                                                                        |5    |
# |Intranet                 |GET /dccstats/stats-hashes.1week.png HTTP/1.1                                                                           |5    |
# |Intranet                 |GET /twiki/bin/view/Main/WebHome HTTP/1.1                                                                               |4    |
# |Intranet                 |GET /mailman/admin/ppwc/members?letter=p HTTP/1.1                                                                       |3    |
# |Intranet                 |GET /mailman/admin/ppwc/members HTTP/1.1                                                                                |3    |
# |Intranet                 |GET /mailman/admin/ppwc HTTP/1.1                                                                                        |2    |
# |Intranet                 |POST /mailman/admin/ppwc/members?letter=p HTTP/1.1                                                                      |2    |
# |Intranet                 |GET / HTTP/1.1                                                                                                          |1    |
# |Intranet                 |GET /mailman/listinfo/ppwc HTTP/1.1                                                                                     |1    |
# |Intranet                 |POST /mailman/options/ppwc/ppwctwentynine@shaw.com HTTP/1.1                                                             |1    |
# |Intranet                 |POST /mailman/admin/ppwc/members/add HTTP/1.1                                                                           |1    |
# |Intranet                 |POST /mailman/admin/ppwc HTTP/1.1                                                                                       |1    |
# |Intranet                 |GET /mailman/listinfo HTTP/1.1                                                                                          |1    |
# |Intranet                 |GET /mailman/admin/ppwc/members/add HTTP/1.1                                                                            |1    |
# |Intranet                 |GET /mailman/admin/ppwc/logout HTTP/1.1                                                                                 |1    |
# |Intranet                 |GET /mailman HTTP/1.1                                                                                                   |1    |
# |Intranet                 |GET /mailman/admin/ppwc/members/list HTTP/1.1                                                                           |1    |
# |Intranet                 |GET /mailman/options/ppwc/ppwctwentynine--at--shaw.com HTTP/1.1                                                         |1    |
# |Intranet                 |GET /mailman/admin/ppwc/general HTTP/1.1                                                                                |1    |
# |Israel                   |GET /dccstats/stats-spam-ratio.1week.png HTTP/1.0                                                                       |1    |
# |Israel                   |GET /dccstats/stats-spam.1month.png HTTP/1.0                                                                            |1    |
# |Israel                   |GET / HTTP/1.0                                                                                                          |1    |
# |Israel                   |GET /dccstats/stats-spam.1year.png HTTP/1.0                                                                             |1    |
# |Israel                   |GET /dccstats/stats-spam-ratio.1year.png HTTP/1.0                                                                       |1    |
# |Israel                   |GET /dccstats/stats-spam.1day.png HTTP/1.0                                                                              |1    |
# |Israel                   |GET /razor.html HTTP/1.0                                                                                                |1    |
# |Israel                   |GET /dccstats/index.html HTTP/1.0                                                                                       |1    |
# |Israel                   |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif HTTP/1.0                                                            |1    |
# |Israel                   |GET /twiki/bin/view/Main/PostfixCommands HTTP/1.0                                                                       |1    |
# |Israel                   |GET /dccstats/stats-hashes.1week.png HTTP/1.0                                                                           |1    |
# |Israel                   |GET /twiki/bin/view/Main/WebHome HTTP/1.0                                                                               |1    |
# |Israel                   |GET /SpamAssassin.html HTTP/1.0                                                                                         |1    |
# |Israel                   |GET /dccstats/stats-spam-ratio.1day.png HTTP/1.0                                                                        |1    |
# |Israel                   |GET /dccstats/stats-hashes.1month.png HTTP/1.0                                                                          |1    |
# |Israel                   |GET /dccstats/stats-hashes.1year.png HTTP/1.0                                                                           |1    |
# |Israel                   |GET /dccstats/stats-spam.1week.png HTTP/1.0                                                                             |1    |
# |Israel                   |GET /dccstats/stats-spam-ratio.1month.png HTTP/1.0                                                                      |1    |
# |Israel                   |GET /twiki/bin/view/Main/LinksOfUse HTTP/1.0                                                                            |1    |
# |Korea                    |GET /icons/PythonPowered.png HTTP/1.1                                                                                   |1    |
# |Korea                    |GET /icons/mailman.jpg HTTP/1.1                                                                                         |1    |
# |Korea                    |GET /icons/gnu-head-tiny.jpg HTTP/1.1                                                                                   |1    |
# |Korea                    |GET /mailman/listinfo/cncce HTTP/1.1                                                                                    |1    |
# |Los Alamos               |GET /razor.html HTTP/1.1                                                                                                |1    |
# |Mexico                   |GET /razor.html HTTP/1.1                                                                                                |1    |
# |Netherlands              |GET /SpamAssassin.html HTTP/1.1                                                                                         |1    |
# |Netherlands              |GET / HTTP/1.1                                                                                                          |1    |
# |Robot                    |GET /robots.txt HTTP/1.0                                                                                                |21   |
# |Robot                    |GET /twiki/bin/view/Main/SanJoseOffice HTTP/1.0                                                                         |2    |
# |Robot                    |GET /twiki/bin/oops/Main/Smtpd_recipient_limit HTTP/1.0                                                                 |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/WikiTopic HTTP/1.0                                                                            |1    |
# |Robot                    |GET /twiki/bin/view/Main/WebSearch HTTP/1.0                                                                             |1    |
# |Robot                    |GET /twiki/bin/view/Sandbox/WebIndex HTTP/1.0                                                                           |1    |
# |Robot                    |GET /twiki/bin/view/Know/WebHome HTTP/1.0                                                                               |1    |
# |Robot                    |GET /twiki/bin/oops/Main/TWikiUsers HTTP/1.0                                                                            |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/InterWikis HTTP/1.0                                                                           |1    |
# |Robot                    |GET /twiki/bin/view/Main/TWi HTTP/1.0                                                                                   |1    |
# |Robot                    |GET /twiki/bin/oops/Main/SpamAssassinTaggingOnly HTTP/1.0                                                               |1    |
# |Robot                    |GET /twiki/bin/oops/Sandbox/WebChanges HTTP/1.0                                                                         |1    |
# |Robot                    |GET /twiki/bin/view/Sandbox/WebChanges HTTP/1.0                                                                         |1    |
# |Robot                    |GET / HTTP/1.0                                                                                                          |1    |
# |Robot                    |GET /twiki/bin/view/Main/WebStatistics HTTP/1.0                                                                         |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/TWikiVariables HTTP/1.0                                                                       |1    |
# |Robot                    |GET /twiki/bin/view/Main/DCCGraphs HTTP/1.0                                                                             |1    |
# |Robot                    |GET /twiki/bin/oops/Main/T HTTP/1.0                                                                                     |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/Wik HTTP/1.0                                                                                  |1    |
# |Robot                    |GET /twiki/bin/view/Main/DCCAndPostFix HTTP/1.0                                                                         |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/TWikiPlannedFeatures HTTP/1.0                                                                 |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/InterwikiPlugin HTTP/1.0                                                                      |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/FileAttachment HTTP/1.0                                                                       |1    |
# |Robot                    |GET /twiki/bin/view/TWiki/2fa HTTP/1.0                                                                                  |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/SvenDowideit HTTP/1.0                                                                         |1    |
# |Robot                    |GET /twiki/bin/oops/Main/Mi HTTP/1.0                                                                                    |1    |
# |Robot                    |GET /twiki/bin/view/Main/MikeMannix HTTP/1.0                                                                            |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/TextFormattingRules HTTP/1.0                                                                  |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/TWikiAccessControl HTTP/1.0                                                                   |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/TablePlugin HTTP/1.0                                                                          |1    |
# |Robot                    |GET /twiki/bin/oops/Know/TopicClassification HTTP/1.0                                                                   |1    |
# |Robot                    |GET /twiki/bin/view/Sandbox/WebPreferences HTTP/1.0                                                                     |1    |
# |Robot                    |GET /twiki/bin/view/Sandbox/WebHome HTTP/1.0                                                                            |1    |
# |Robot                    |GET /twiki/bin/oops/Main/TWi HTTP/1.0                                                                                   |1    |
# |Robot                    |GET /twiki/bin/oops/Know/WebStatistics HTTP/1.0                                                                         |1    |
# |Robot                    |GET /twiki/bin/oops/Main/WebStatistics HTTP/1.0                                                                         |1    |
# |Robot                    |GET /twiki/bin/view/Main/VishaalGolam HTTP/1.0                                                                          |1    |
# |Robot                    |GET /twiki/bin/oops/Know/PublicSupported HTTP/1.0                                                                       |1    |
# |Robot                    |GET /twiki/bin/view/Main/WebNotify HTTP/1.0                                                                             |1    |
# |Robot                    |GET /twiki/bin/oops/Main/TWiki HTTP/1.0                                                                                 |1    |
# |Robot                    |GET /twiki/bin/view/Main/WebPreferences HTTP/1.0                                                                        |1    |
# |Robot                    |GET /twiki/bin/oops/Know/WinDoze95Crash HTTP/1.0                                                                        |1    |
# |Robot                    |GET /twiki/bin/view/Know/WebStatistics HTTP/1.0                                                                         |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/RegularExp HTTP/1.0                                                                           |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/Mana HTTP/1.0                                                                                 |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/NicholasLee HTTP/1.0                                                                          |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/MoveTopic HTTP/1.0                                                                            |1    |
# |Robot                    |GET /twiki/bin/view/TWiki/d43 HTTP/1.0                                                                                  |1    |
# |Robot                    |GET /twiki/bin/view/Main/LondonOffice HTTP/1.0                                                                          |1    |
# |Robot                    |GET /twiki/bin/view/Main/TWikiAdminGroup HTTP/1.0                                                                       |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/JohnAltstadt HTTP/1.0                                                                         |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/1000 HTTP/1.0                                                                                 |1    |
# |Robot                    |GET /twiki/bin/oops/Main/ThanadonSomdee HTTP/1.0                                                                        |1    |
# |Robot                    |GET /twiki/bin/oops/Main/KevinWGage HTTP/1.0                                                                            |1    |
# |Robot                    |GET /twiki/bin/oops/Sandbox/WebStatistics HTTP/1.0                                                                      |1    |
# |Robot                    |GET /twiki/bin/view/Main/WebTopicList HTTP/1.0                                                                          |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/WikiWikiClones HTTP/1.0                                                                       |1    |
# |Robot                    |GET /twiki/bin/oops/TWiki/WebChangesAlert HTTP/1.0                                                                      |1    |
# |Robot                    |GET /twiki/bin/view/Main/SimonMudd HTTP/1.0                                                                             |1    |
# |Spain                    |GET /twiki/bin/view/Main/PostSuper HTTP/1.1                                                                             |1    |
# |Spain                    |GET /twiki/bin/view/Main/PostfixCommands HTTP/1.1                                                                       |1    |
# |Spain                    |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif HTTP/1.1                                                            |1    |
# |Spain                    |GET /twiki/bin/view/Main/WebHome HTTP/1.1                                                                               |1    |
# |Taiwan                   |GET /M83A HTTP/1.0                                                                                                      |1    |
# |United Kingdom           |GET /favicon.ico HTTP/1.1                                                                                               |2    |
# |United Kingdom           |GET /razor.html HTTP/1.1                                                                                                |1    |
# |United Kingdom           |GET /razor.html HTTP/1.0                                                                                                |1    |
# |United Kingdom           |GET / HTTP/1.1                                                                                                          |1    |
# |United Kingdom           |GET /DCC.html HTTP/1.1                                                                                                  |1    |
# |United States            |GET /favicon.ico HTTP/1.1                                                                                               |8    |
# |United States            |GET /twiki/bin/view/Main/WebHome HTTP/1.1                                                                               |8    |
# |United States            |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif HTTP/1.1                                                            |6    |
# |United States            |GET /twiki/bin/view/Main/SpamAssassinAndPostFix HTTP/1.1                                                                |3    |
# |United States            |GET / HTTP/1.1                                                                                                          |3    |
# |United States            |GET /twiki/bin/view/Main/SpamAssassinTaggingOnly HTTP/1.1                                                               |3    |
# |United States            |HEAD /twiki/bin/view/Main/SpamAssassinDeleting HTTP/1.1                                                                 |3    |
# |United States            |GET /twiki/bin/view/Main/WebHome HTTP/1.0                                                                               |2    |
# |United States            |GET /twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC HTTP/1.1                                                          |2    |
# |United States            |GET /twiki/bin/view/Main/ConfigurationVariables HTTP/1.0                                                                |1    |
# |United States            |GET /twiki/pub/TWiki/TWikiDocGraphics/help.gif HTTP/1.0                                                                 |1    |
# |United States            |GET /twiki/bin/view/Main/RelayGateway HTTP/1.1                                                                          |1    |
# |United States            |GET /twiki/bin/view/Main/SpamAssassinTaggingOnly HTTP/1.0                                                               |1    |
# |United States            |GET /dccstats/stats-hashes.1month.png HTTP/1.1                                                                          |1    |
# |United States            |GET /twiki/bin/view/Main/PostSuper HTTP/1.0                                                                             |1    |
# |United States            |GET /twiki/bin/view/Main/RelayGateway HTTP/1.0                                                                          |1    |
# |United States            |GET /twiki/bin/view/Main/PostfixCommands HTTP/1.1                                                                       |1    |
# |United States            |GET /dccstats/stats-spam.1year.png HTTP/1.1                                                                             |1    |
# |United States            |GET /twiki/bin/view/Main/PostfixCmd HTTP/1.0                                                                            |1    |
# |United States            |GET /dccstats/stats-spam-ratio.1month.png HTTP/1.1                                                                      |1    |
# |United States            |GET /AmavisNew.html HTTP/1.1                                                                                            |1    |
# |United States            |GET /mailman/listinfo/webber HTTP/1.1                                                                                   |1    |
# |United States            |GET /twiki/bin/view/Main/SpamAssassinDeleting HTTP/1.1                                                                  |1    |
# |United States            |GET /dccstats/stats-hashes.1year.png HTTP/1.1                                                                           |1    |
# |United States            |GET /twiki/bin/view/Main/RBLsHowTo HTTP/1.0                                                                             |1    |
# |United States            |GET /dccstats/stats-hashes.1week.png HTTP/1.1                                                                           |1    |
# |United States            |GET /mailman HTTP/1.1                                                                                                   |1    |
# |United States            |GET /icons/mailman.jpg HTTP/1.0                                                                                         |1    |
# |United States            |GET /twiki/bin/view/Main/Relay_Domains HTTP/1.1                                                                         |1    |
# |United States            |GET /razor.html HTTP/1.0                                                                                                |1    |
# |United States            |GET /twiki/bin/edit/Main/Propagate_unmatched_extensions?topicparent=Main.ConfigurationVariables HTTP/1.0                |1    |
# |United States            |GET /twiki/bin/view/Main/TWikiGroups HTTP/1.1                                                                           |1    |
# |United States            |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif HTTP/1.0                                                            |1    |
# |United States            |GET /twiki/bin/view/Main/SideBar HTTP/1.0                                                                               |1    |
# |United States            |GET /twiki/bin/view/Main/SpamAssassinAndPostFix HTTP/1.0                                                                |1    |
# |United States            |GET /dccstats/stats-spam.1month.png HTTP/1.1                                                                            |1    |
# |United States            |GET /dccstats/stats-spam.1week.png HTTP/1.1                                                                             |1    |
# |United States            |GET /twiki/bin/view/Main/TWikiAdminGroup HTTP/1.1                                                                       |1    |
# |United States            |GET /icons/PythonPowered.png HTTP/1.0                                                                                   |1    |
# |United States            |GET /mailman/listinfo HTTP/1.1                                                                                          |1    |
# |United States            |GET /dccstats/stats-spam-ratio.1year.png HTTP/1.1                                                                       |1    |
# |United States            |GET /twiki/bin/view/Main/VerifingGatway HTTP/1.1                                                                        |1    |
# |United States            |GET /SpamAssassin.html HTTP/1.1                                                                                         |1    |
# |United States            |GET /dccstats/index.html HTTP/1.1                                                                                       |1    |
# |United States            |GET /mailman/listinfo/ppwc HTTP/1.0                                                                                     |1    |
# |United States            |GET /dccstats/stats-spam.1day.png HTTP/1.1                                                                              |1    |
# |United States            |GET /razor.html HTTP/1.1                                                                                                |1    |
# |United States            |GET /LateEmail.html HTTP/1.0                                                                                            |1    |
# |United States            |GET /icons/gnu-head-tiny.jpg HTTP/1.0                                                                                   |1    |
# |United States            |GET /mailman/listinfo/ppwc HTTP/1.1                                                                                     |1    |
# |United States            |GET /dccstats/stats-spam-ratio.1week.png HTTP/1.1                                                                       |1    |
# |United States            |GET /AmavisNew.html HTTP/1.0                                                                                            |1    |
# |United States            |GET /dccstats/stats-spam-ratio.1day.png HTTP/1.1                                                                        |1    |
# |United States            |GET /rejected.html HTTP/1.1                                                                                             |1    |
# |United States            |GET /twiki/bin/view/Main/DCC HTTP/1.1                                                                                   |1    |
# |United States            |GET /twiki/bin/view/Main/LinksOfUse HTTP/1.0                                                                            |1    |
# |United States            |GET /twiki/bin/view/Main/PostfixCommands HTTP/1.0                                                                       |1    |
# |United States            |GET /twiki/bin/view/Main/SpamAssassin HTTP/1.1                                                                          |1    |
# |Unknown Location         |GET / HTTP/1.1                                                                                                          |15   |
# |Unknown Location         |GET /twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif HTTP/1.1                                                            |14   |
# |Unknown Location         |GET /twiki/bin/view/Main/WebHome HTTP/1.1                                                                               |13   |
# |Unknown Location         |GET /favicon.ico HTTP/1.1                                                                                               |10   |
# |Unknown Location         |GET /twiki/bin/view/Main/SpamAssassinTaggingOnly HTTP/1.1                                                               |10   |
# |Unknown Location         |GET /razor.html HTTP/1.1                                                                                                |9    |
# |Unknown Location         |GET /twiki/bin/view/Main/SpamAssassinAndPostFix HTTP/1.1                                                                |8    |
# ...
# |Unknown Location         |GET /twiki/bin/edit/Main/Max_use?topicparent=Main.ConfigurationVariables HTTP/1.1                                       |1    |
# |Unknown Location         |GET /images/msgops.JPG HTTP/1.0                                                                                         |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/TWikiGuest HTTP/1.0                                                                            |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/TextFormattingRules?rev=r1.21 HTTP/1.1                                                        |1    |
# |Unknown Location         |GET /twiki/bin/edit/TWiki/SvenDowideit?t=1078710644 HTTP/1.1                                                            |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/WebPreferences?rev=r1.10 HTTP/1.1                                                              |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/TablePlugin?skin=print HTTP/1.1                                                               |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/Relayhost?topicparent=Main.ConfigurationVariables HTTP/1.0                                     |1    |
# |Unknown Location         |GET /twiki/bin/search/TWiki/?scope=topic&regex=on&search=^y HTTP/1.1                                                    |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/WelcomeGuest?topicparent=Main.WebHome HTTP/1.1                                                 |1    |
# |Unknown Location         |GET /twiki/bin/rdiff/Main/TokyoOffice?rev1=1.2&rev2=1.1 HTTP/1.1                                                        |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/TokyoOffice?rev=1.2 HTTP/1.1                                                                   |1    |
# |Unknown Location         |GET /twiki/bin/edit/TWiki/TWikiRegistration?t=1078670224 HTTP/1.1                                                       |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/Max_idle?topicparent=Main.ConfigurationVariables HTTP/1.0                                      |1    |
# |Unknown Location         |GET /twiki/bin/search/Main/?scope=topic&regex=on&search=^g HTTP/1.1                                                     |1    |
# |Unknown Location         |GET /dccstats/ HTTP/1.0                                                                                                 |1    |
# |Unknown Location         |GET /twiki/bin/rdiff/TWiki/KevinKinnell?rev1=1.5&rev2=1.4 HTTP/1.1                                                      |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/WebPreferences?rev=r1.4 HTTP/1.1                                                               |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/Mydestination?topicparent=Main.ConfigurationVariables HTTP/1.1                                 |1    |
# |Unknown Location         |GET /twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Web%20*Preferences[^A-Za-z] HTTP/1.1                |1    |
# |Unknown Location         |GET /twiki/bin/rdiff/TWiki/RyanFreebern?rev1=1.2&rev2=1.1 HTTP/1.1                                                      |1    |
# |Unknown Location         |GET /twiki/bin/rdiff/TWiki/AlWilliams?rev1=1.3&rev2=1.2 HTTP/1.1                                                        |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/TextFormattingRules?rev=r1.35 HTTP/1.1                                                        |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/TWikiUsers?rev=1.21 HTTP/1.1                                                                   |1    |
# |Unknown Location         |GET /twiki/bin/oops/TWiki/HaroldGottschalk?template=oopsmore&param1=1.3&param2=1.3 HTTP/1.1                             |1    |
# |Unknown Location         |GET /twiki/bin/rdiff/TWiki/TextFormattingRules?rev1=1.36&rev2=1.35 HTTP/1.1                                             |1    |
# |Unknown Location         |GET /mailman/admin/hs_support HTTP/1.1                                                                                  |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/TextFormattingRules?rev=r1.37 HTTP/1.1                                                        |1    |
# |Unknown Location         |GET /cgi-bin/mailgraph.cgi/mailgraph_2.png HTTP/1.1                                                                     |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/WebHome?rev=1.25 HTTP/1.0                                                                      |1    |
# |Unknown Location         |GET /mailman/listinfo/administration HTTP/1.1                                                                           |1    |
# |Unknown Location         |GET /twiki/bin/edit/TWiki/WikiNotation?t=1078726052 HTTP/1.1                                                            |1    |
# |Unknown Location         |GET /mailman/admin/artsscience HTTP/1.1                                                                                 |1    |
# |Unknown Location         |GET /twiki/bin/rdiff/Main/WebIndex?rev1=1.2&rev2=1.1 HTTP/1.1                                                           |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/Relayhost?topicparent=Main.ConfigurationVariables HTTP/1.1                                     |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/SpamAssassin?t=1078709979 HTTP/1.1                                                             |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/WebPreferences?rev=1.14 HTTP/1.1                                                               |1    |
# |Unknown Location         |GET /cgi-bin/mailgraph.cgi/mailgraph_0_err.png HTTP/1.1                                                                 |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/PeterThoeny HTTP/1.1                                                                           |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/TWikiPreferences?topicparent=Main.WebHome HTTP/1.1                                             |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/AlWilliams?rev=1.1 HTTP/1.1                                                                   |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/WebNotify?rev=r1.6 HTTP/1.0                                                                    |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/PostSuper?rev=r1.1 HTTP/1.1                                                                    |1    |
# |Unknown Location         |GET /twiki/bin/rdiff/TWiki/KlausWriessnegger?rev1=1.2&rev2=1.1 HTTP/1.1                                                 |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/ThanadonSomdee HTTP/1.1                                                                        |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/PostfixCmd HTTP/1.0                                                                            |1    |
# |Unknown Location         |GET /twiki/bin/rdiff/TWiki/PeterFokkinga?rev1=1.4&rev2=1.3 HTTP/1.1                                                     |1    |
# |Unknown Location         |GET /images/image004.jpg HTTP/1.1                                                                                       |1    |
# |Unknown Location         |GET /twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Inter%20*Wikis[^A-Za-z] HTTP/1.1                    |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/TWikiHistory?rev=r1.50 HTTP/1.1                                                               |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/TWikiGroups HTTP/1.1                                                                           |1    |
# |Unknown Location         |GET /twiki/bin/edit/Sandbox/TestTopic7?topicparent=Sandbox.WebHome HTTP/1.1                                             |1    |
# |Unknown Location         |GET /mailman/private/business/ HTTP/1.1                                                                                 |1    |
# |Unknown Location         |GET /twiki/bin/search/Main/?scope=topic&regex=on&search=^t HTTP/1.1                                                     |1    |
# |Unknown Location         |GET /images/image005.jpg HTTP/1.1                                                                                       |1    |
# |Unknown Location         |GET /twiki/bin/attach/TWiki/TablePlugin HTTP/1.1                                                                        |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/TWikiGuest?rev=1.4 HTTP/1.1                                                                    |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/Smtpd_history_flush_threshold?topicparent=Main.ConfigurationVariables HTTP/1.1                 |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/WelcomeGuest HTTP/1.1                                                                          |1    |
# |Unknown Location         |GET /twiki/bin/edit/TWiki/NewTopic?topicparent=TWiki.WikiSyntax HTTP/1.1                                                |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/TWikiGuest?skin=print HTTP/1.1                                                                 |1    |
# |Unknown Location         |GET /twiki/bin/rdiff/TWiki/WebTopicEditTemplate?rev1=1.5&rev2=1.4 HTTP/1.1                                              |1    |
# |Unknown Location         |GET /twiki/bin/search/Main/SearchResult?search=%5C.*&scope=topic&order=modified&reverse=on&regex=on&nosearch=on HTTP/1.0|1    |
# |Unknown Location         |GET /mailman/private/hs_support/ HTTP/1.1                                                                               |1    |
# |Unknown Location         |GET /twiki/bin/view/Main/WebStatistics?skin=print HTTP/1.1                                                              |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/Maps_rbl_reject_code?topicparent=Main.ConfigurationVariables HTTP/1.1                          |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/Smtp_data_init_timeout?topicparent=Main.ConfigurationVariables HTTP/1.0                        |1    |
# |Unknown Location         |GET /twiki/bin/attach/TWiki/WebPreferences HTTP/1.1                                                                     |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/WebTopicEditTemplate HTTP/1.1                                                                 |1    |
# |Unknown Location         |GET /mailman/listinfo/dentalstudies HTTP/1.1                                                                            |1    |
# |Unknown Location         |GET /mailman/listinfo/hs_rcafaculty HTTP/1.1                                                                            |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/WebSearch?rev=1.11 HTTP/1.1                                                                   |1    |
# |Unknown Location         |GET /twiki/bin/oops/TWiki/TWikiHistory?template=oopsmore&param1=1.61&param2=1.61 HTTP/1.1                               |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/TWikiRegistration?rev=r1.7 HTTP/1.1                                                           |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/DontNotify?rev=1.1 HTTP/1.1                                                                   |1    |
# |Unknown Location         |GET /mailman/private/artsscience/ HTTP/1.1                                                                              |1    |
# |Unknown Location         |GET /twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Web%20*Changes[^A-Za-z] HTTP/1.1                     |1    |
# |Unknown Location         |GET /mailman/listinfo/purchasing HTTP/1.1                                                                               |1    |
# |Unknown Location         |GET /twiki/bin/rdiff/Main/PeterThoeny HTTP/1.0                                                                          |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/Export_environment?topicparent=Main.ConfigurationVariables HTTP/1.1                            |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/MartinCleaver HTTP/1.1                                                                        |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/Smtpd_etrn_restrictions?topicparent=Main.ConfigurationVariables HTTP/1.1                       |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/Deliver_lock_attempts?topicparent=Main.ConfigurationVariables HTTP/1.1                         |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/DavidWarman HTTP/1.1                                                                          |1    |
# |Unknown Location         |GET /SpamAssassin.html HTTP/1.0                                                                                         |1    |
# |Unknown Location         |GET /twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Wiki%20*Notation[^A-Za-z] HTTP/1.1                  |1    |
# |Unknown Location         |GET /twiki/bin/edit/TWiki/RichardDonkin?t=1078691832 HTTP/1.1                                                           |1    |
# |Unknown Location         |GET /twiki/bin/view/TWiki/WikiName HTTP/1.1                                                                             |1    |
# |Unknown Location         |GET /twiki/bin/edit/Main/TokyoOffice?t=1078706364 HTTP/1.1                                                              |1    |
# |Wherever You Want to Ship|GET / HTTP/1.0                                                                                                          |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-spam.1year.png HTTP/1.0                                                                             |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-spam.1day.png HTTP/1.0                                                                              |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-spam.1week.png HTTP/1.0                                                                             |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-spam.1month.png HTTP/1.0                                                                            |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-spam-ratio.1week.png HTTP/1.0                                                                       |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-spam-ratio.1day.png HTTP/1.0                                                                        |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-hashes.1week.png HTTP/1.0                                                                           |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-spam-ratio.1year.png HTTP/1.0                                                                       |1    |
# |Wherever You Want to Ship|GET /dccstats/index.html HTTP/1.0                                                                                       |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-hashes.1month.png HTTP/1.0                                                                          |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-hashes.1year.png HTTP/1.0                                                                           |1    |
# |Wherever You Want to Ship|GET /dccstats/stats-spam-ratio.1month.png HTTP/1.0                                                                      |1    |
# +-------------------------+------------------------------------------------------------------------------------------------------------------------+-----+

# %% [markdown]
# # Part 2: Reporting Tasks Based on Student / Course Data
#
#
#
# 1.   Find the names of the students that have taken at least one of the courses with the greatest difficulty.
# 2.   Find the average course difficulty of the classes that are taken by each student. Print average course difficulty of 0 if a student hasn't taken any classes (hint, use left outer or right outer join).

# %%
# Data for exercises below

# course information: course code, difficulty (1-3)
courses = [("CSC365", 1),
           ("CSC369", 1),
           ("CSC430", 3),
           ("CSC469", 2)]
courses_df = spark.createDataFrame(courses, ["Course", "Difficulty"])
courses_rdd = courses_df.rdd.map(tuple)

# student information: unique student ID, name, email
students = [(1,"Nikita","Trevett","ntrevett0@abc.net.au"),
            (2,"Jacquenette","Tolson","jtolson1@ucoz.com"),
            (3,"Helsa","St Ledger","hstledger2@elpais.com"),
            (4,"Eli","Golland","egolland3@wordpress.com"),
            (5,"Amitie","Mytton","amytton4@mit.edu"),
            (6,"Adan","Holtum","aholtum1i@amazon.co.uk")]
students_df = spark.createDataFrame(students, ["ID", "FirstName", "LastName", "Email"])
students_rdd = students_df.rdd.map(tuple)


# student grades: student ID, course code, grade earned
student_grades = [(1, "CSC365", "A"),
                  (1, "CSC369", "A-"),
                  (1, "CSC469", "B"),
                  (2, "CSC369", "B"),
                  (3, "CSC365", "A"),
                  (3, "CSC430", "B")]
student_grades_df = spark.createDataFrame(student_grades, ["StudentId", "Course", "Grade"])
student_grades_rdd = student_grades_df.rdd.map(tuple)

courses_df.show(truncate=False)
students_df.show(truncate=False)
student_grades_df.show(truncate=False)
# Out:
# +------+----------+
# |Course|Difficulty|
# +------+----------+
# |CSC365|1         |
# |CSC369|1         |
# |CSC430|3         |
# |CSC469|2         |
# +------+----------+
#
# +---+-----------+---------+-----------------------+
# |ID |FirstName  |LastName |Email                  |
# +---+-----------+---------+-----------------------+
# |1  |Nikita     |Trevett  |ntrevett0@abc.net.au   |
# |2  |Jacquenette|Tolson   |jtolson1@ucoz.com      |
# |3  |Helsa      |St Ledger|hstledger2@elpais.com  |
# |4  |Eli        |Golland  |egolland3@wordpress.com|
# |5  |Amitie     |Mytton   |amytton4@mit.edu       |
# |6  |Adan       |Holtum   |aholtum1i@amazon.co.uk |
# +---+-----------+---------+-----------------------+
#
# +---------+------+-----+
# |StudentId|Course|Grade|
# +---------+------+-----+
# |1        |CSC365|A    |
# |1        |CSC369|A-   |
# |1        |CSC469|B    |
# |2        |CSC369|B    |
# |3        |CSC365|A    |
# |3        |CSC430|B    |
# +---------+------+-----+

# %%
s = students_df.withColumnRenamed("ID", "StudentId")
s.join(student_grades_df, "StudentId").show()
# Out:
# +---------+-----------+---------+--------------------+------+-----+
# |StudentId|  FirstName| LastName|               Email|Course|Grade|
# +---------+-----------+---------+--------------------+------+-----+
# |        1|     Nikita|  Trevett|ntrevett0@abc.net.au|CSC365|    A|
# |        1|     Nikita|  Trevett|ntrevett0@abc.net.au|CSC369|   A-|
# |        1|     Nikita|  Trevett|ntrevett0@abc.net.au|CSC469|    B|
# |        2|Jacquenette|   Tolson|   jtolson1@ucoz.com|CSC369|    B|
# |        3|      Helsa|St Ledger|hstledger2@elpais...|CSC365|    A|
# |        3|      Helsa|St Ledger|hstledger2@elpais...|CSC430|    B|
# +---------+-----------+---------+--------------------+------+-----+

# %% [markdown]
# # (A) RDD Implementations

# %%
# RDD implementation
# (1) Find the names of the students that have taken at least one of the courses with the greatest difficulty.
max_difficulty = courses_rdd.map(lambda x: x[1]).max()
filtered_courses_rdd = (courses_rdd
                        .filter(lambda x: x[1] == max_difficulty)
                        .map(lambda x: (x[0], None)))
students_and_grades_rdd = student_grades_rdd.join(students_rdd)
filtered_students_rdd = (students_and_grades_rdd
                         .map(lambda x: ( x[1][0], ( x[1][1] )))
                         .join(filtered_courses_rdd)
                         .map(lambda x: x[1][0])
                         .distinct())
for student in filtered_students_rdd.collect():
  print(f"{student}")
# Out:
# Helsa

# %%
# RDD implementation
# (2) Find the average course difficulty of the classes that are taken by each student. Print average course difficulty of 0
#     if a student hasn't taken any classes (hint, use left outer or right outer join).
students_and_grades_rdd = student_grades_rdd.rightOuterJoin(students_rdd)
students_and_difficulties_rdd = (students_and_grades_rdd
                                  .map(lambda x: (x[1][0], x[1][1]))
                                  .leftOuterJoin(courses_rdd)
                                  .map(lambda x: (x[1][0], (x[1][1], 1)) if x[0] else (x[1][0], (0, 0)))
                                  .reduceByKey(lambda x, y: (x[0] + y[0], x[1] + y[1]))
                                  .map(lambda x: (x[0], round(x[1][0]/x[1][1], 1) if x[1][0] and x[1][1] else 0.0))
                                  .sortBy(lambda x: x[1])
                                  )
for student, avg in students_and_difficulties_rdd.collect():
  print(f"{student}\t{avg}")
# Out:
# Eli	0.0
# Adan	0.0
# Amitie	0.0
# Jacquenette	1.0
# Nikita	1.3
# Helsa	2.0

# %% [markdown]
# # (B) DataFrame Implementations
#
# Spark SQL is not permitted for these exercises.

# %%
# DataFrame implementation
# (1) Find the names of the students that have taken at least one of the courses with the greatest difficulty.
max_difficulty = courses_df.agg({"Difficulty": "max"}).collect()[0][0]
filtered_courses_df = courses_df.filter(courses_df.Difficulty == max_difficulty)
joined_df = (student_grades_df
             .join(students_df.withColumnRenamed("ID", "StudentID"), "StudentID")
             .join(filtered_courses_df, "Course")
             .select("FirstName")
             .distinct())
joined_df.show()
# Out:
# +---------+
# |FirstName|
# +---------+
# |    Helsa|
# +---------+

# %%
# DataFrame implementation
# (2) Find the average course difficulty of the classes that are taken by each student. Print average course difficulty of 0
#     if a student hasn't taken any classes (hint, use left outer or right outer join).
gradebook_df = student_grades_df.join(students_df.withColumnRenamed("ID", "StudentID"), "StudentID", 'right_outer')
gradebook_with_diff_df = gradebook_df.join(courses_df, 'Course', 'leftouter')
result_df = (gradebook_with_diff_df
                                  .groupBy('FirstName')
                                  .avg('Difficulty')
                                  .withColumnRenamed('avg(Difficulty)', 'Difficulty')
                                  .fillna(0))
result_df = result_df.withColumn('Difficulty', (result_df['Difficulty'] * 10).cast('integer') / 10)
result_df.show()
# Out:
# +-----------+----------+
# |  FirstName|Difficulty|
# +-----------+----------+
# |     Amitie|       0.0|
# |       Adan|       0.0|
# |        Eli|       0.0|
# |Jacquenette|       1.0|
# |     Nikita|       1.3|
# |      Helsa|       2.0|
# +-----------+----------+
